# %% [markdown]
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)
#
#  * 2023/11/06 - updated
#  * 2023/09/21 - updated
#  * 2022/06/28 - updated
#  * 2021/12/13 - initial revision
#
# <img align="left" width="50%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" >

# %% [markdown]
# ### Read exported bibliodatabase files exposed in 'Included/not included papers'

# %%
import pandas as pd
import csv

# %%
tagDate = '20231101'

# %%
def check_numberFields(file, nbFields):
    with open(file, mode ='r') as file:
        csvFile = csv.reader(file, delimiter=';')
        lineN = 0
        for lines in csvFile:
            lineN = lineN + 1
            if len(lines) != nbFields:
                print(lineN, len(lines))

# %%
dfArray = []

# %%
file = 'OAICCincomplete_' + tagDate + '.utf8'
check_numberFields(file, 4)

# %%
df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Not included'
df['Reason for non inclusion'] = '< 2 carbonate chemistry parameters'

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Adeleke, B., Robertson-Andersson, D., & Moodle...
# 1  Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 2  Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 3  Aires, T., Serebryakova, A., Viard, F., Serrão...
# 4  Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
#
#                                  DOI       Country  Year  \
# 0  doi:10.1016/j.heliyon.2020.e04744  South Africa  2020
# 1              doi:10.1111/jfd.12417    EU-Austria  2016
# 2             doi:10.3390/min4010145           USA  2014
# 3             doi:10.7717/peerj.4377   EU-Portugal  2018
# 4     doi:10.17576/mjas-2019-2306-10      Malaysia  2019
#
#   Included/Not included            Reason for non inclusion
# 0          Not included  < 2 carbonate chemistry parameters
# 1          Not included  < 2 carbonate chemistry parameters
# 2          Not included  < 2 carbonate chemistry parameters
# 3          Not included  < 2 carbonate chemistry parameters
# 4          Not included  < 2 carbonate chemistry parameters

# %%
file = 'OAICCnoanswer_' + tagDate + '.utf8'
check_numberFields(file, 4)

# %%
df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Not included'
df['Reason for non inclusion'] = 'No answer from authors'

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Achlatis, M., van der Zande, R. M., Schönberg,...
# 1  Agnalt, A.-L., Grefsrud, E. S., Farestveit, E....
# 2  Aguayo, P., Campos, V. L., Henríquez, C., Oliv...
# 3  Albert, G., Hepburn, C. D., Pajusalu, L., Paal...
# 4  Albright, R., Bland, C., Gillette, P., Serafy,...
#
#                                  DOI     Country  Year Included/Not included  \
# 0     doi:10.1038/s41598-017-10947-1   Australia  2017          Not included
# 1        doi:10.5194/bg-10-7883-2013   EU-Norway  2013          Not included
# 2  doi:10.3390/microorganisms8121924       Chile  2020          Not included
# 3     doi:10.1007/s10811-019-01953-z  EU-Estonia  2019          Not included
# 4    doi:10.1016/j.jembe.2012.05.017         USA  2012          Not included
#
#   Reason for non inclusion
# 0   No answer from authors
# 1   No answer from authors
# 2   No answer from authors
# 3   No answer from authors
# 4   No answer from authors

# %%
file = 'OAICCdatalost_' + tagDate + '.utf8'
check_numberFields(file, 4)

# %%
df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Not included'
df['Reason for non inclusion'] = 'Data lost'

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Broecker, W. S., Langdon, C., & Takahashi, T.,...
# 1  Burkhardt, S., Amoroso, G., Riebesell, U., & S...
# 2  Burkhardt, S., & Riebesell, U., 1997. CO2 avai...
# 3  Burkhardt, S., Riebesell, U., & Zondervan, I.,...
# 4  Burkhardt, S., Zondervan, I., & Riebesell, U.,...
#
#                                  DOI     Country  Year Included/Not included  \
# 0           doi:10.1029/2000GB001350         USA  2001          Not included
# 1      doi:10.4319/lo.2001.46.6.1378  EU-Germany  2001          Not included
# 2             doi:10.3354/meps155067  EU-Germany  1997          Not included
# 3  doi:10.1016/S0016-7037(99)00217-3  EU-Germany  1999          Not included
# 4      doi:10.4319/lo.1999.44.3.0683  EU-Germany  1999          Not included
#
#   Reason for non inclusion
# 0                Data lost
# 1                Data lost
# 2                Data lost
# 3                Data lost
# 4                Data lost

# %%
file = 'OAICCdb_' + tagDate + '.utf8'
check_numberFields(file, 5)

# %%
df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'DOI_PANGAEA', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['DOI_PANGAEA'] = df['DOI_PANGAEA'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Included'
df['Reason for non inclusion'] = ''

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Ab Lah, R., Kelaher, B. P., Bucher, D., & Benk...
# 1  Abarca-Ortega, A., Muñoz-Moya, E., Pacheco Ala...
# 2  Aberle, N., Schulz, K. G., Stuhr, A., Malzahn,...
# 3  Agostini, S., Fujimura, H., Higuchi, T., Yuyam...
# 4  Agostini, S., Harvey, B. P., Milazzo, M., Wada...
#
#                                    DOI             DOI_PANGAEA     Country  \
# 0  doi:10.1016/j.marenvres.2018.08.009  10.1594/PANGAEA.902088    Malaysia
# 1        doi:10.3389/fbioe.2021.813537  10.1594/PANGAEA.945534       Chile
# 2          doi:10.5194/bg-10-1471-2013  10.1594/PANGAEA.832403  EU-Germany
# 3       doi:10.1016/j.crvi.2013.07.003  10.1594/PANGAEA.835319       Japan
# 4                doi:10.1111/gcb.15749  10.1594/PANGAEA.944056       Japan
#
#    Year Included/Not included Reason for non inclusion
# 0  2018              Included
# 1  2022              Included
# 2  2013              Included
# 3  2013              Included
# 4  2021              Included

# %%
df = pd.concat(dfArray, sort=False)
print(len(df))

df[['Reference', 'DOI', 'DOI_PANGAEA', 'Included/Not included', 'Reason for non inclusion', 'Country', 'Year']]\
    .to_csv('OAICC_' + tagDate + '.csv', index=False, encoding='utf_8', quoting=csv.QUOTE_ALL)
# Out:
# 3665

# %%
df
# Out:
#                                               Reference  \
# 0     Adeleke, B., Robertson-Andersson, D., & Moodle...
# 1     Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 2     Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 3     Aires, T., Serebryakova, A., Viard, F., Serrão...
# 4     Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
# ...                                                 ...
# 1549  Zittier, Z. M. C., Hirse, T., & Pörtner, H.-O....
# 1550  Ziveri, P., Passaro, M., Incarbona, A., Milazz...
# 1551  Zlatkin, R. L., & Heuer, R. M., 2019. Ocean ac...
# 1552  Zondervan, I., Rost, B., & Riebesell, U., 2002...
# 1553  Zondervan, I., Zeebe, R. E., Rost, B., & Riebe...
#
#                                     DOI       Country  Year  \
# 0     doi:10.1016/j.heliyon.2020.e04744  South Africa  2020
# 1                 doi:10.1111/jfd.12417    EU-Austria  2016
# 2                doi:10.3390/min4010145           USA  2014
# 3                doi:10.7717/peerj.4377   EU-Portugal  2018
# 4        doi:10.17576/mjas-2019-2306-10      Malaysia  2019
# ...                                 ...           ...   ...
# 1549      doi:10.1007/s00227-012-2073-8    EU-Germany  2013
# 1550          doi:10.1086/BBLv226n3p282      EU-Spain  2014
# 1551            doi:10.1098/rsos.191041           USA  2019
# 1552  doi:10.1016/S0022-0981(02)00037-0    EU-Germany  2002
# 1553           doi:10.1029/2000GB001321    EU-Germany  2001
#
#      Included/Not included            Reason for non inclusion  \
# 0             Not included  < 2 carbonate chemistry parameters
# 1             Not included  < 2 carbonate chemistry parameters
# 2             Not included  < 2 carbonate chemistry parameters
# 3             Not included  < 2 carbonate chemistry parameters
# 4             Not included  < 2 carbonate chemistry parameters
# ...                    ...                                 ...
# 1549              Included
# 1550              Included
# 1551              Included
# 1552              Included
# 1553              Included
#
#                  DOI_PANGAEA
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1549  10.1594/PANGAEA.821402
# 1550  10.1594/PANGAEA.838830
# 1551  10.1594/PANGAEA.912287
# 1552  10.1594/PANGAEA.726883
# 1553  10.1594/PANGAEA.726883
#
# [3665 rows x 7 columns]

# %%
df.rename(columns={"Country": "Country/Region"}, inplace=True)
df[['Reference', 'DOI', 'DOI_PANGAEA', 'Included/Not included', 'Reason for non inclusion', 'Country/Region', 'Year']].to_csv('OAICC_' + tagDate + '.csv', index=False, encoding='utf_8', quoting=csv.QUOTE_ALL)

# %%
df = pd.read_csv('OAICC_' + tagDate + '.csv',  encoding = 'utf_8')
df[0:20]
# Out:
#                                             Reference  \
# 0   Adeleke, B., Robertson-Andersson, D., & Moodle...
# 1   Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 2   Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 3   Aires, T., Serebryakova, A., Viard, F., Serrão...
# 4   Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
# 5   Al-Janabi, B., Kruse, I., Graiff, A., Winde, V...
# 6   Alenius, B., & Munguia, P., 2012. Effects of p...
# 7   Allen, R., Hoffmann, L. J., Law, C. S., & Summ...
# 8   Allison, N., Cole, C., Hintz, C., Hintz, K., &...
# 9   Almén, A.-K., Vehmaa, A., Brutemark, A., Bach,...
# 10  Almén, A.-K., Vehmaa, A., Brutemark, A., & Eng...
# 11  Almut, G., & Bamber, S., 2013. Behavioural res...
# 12  Alvares Leite Figueiredo, D., Branco, P. C., A...
# 13  Amado-Filho, G. M., Moura, R. L., Bastos, A. C...
# 14  Amaral, V., Cabral, H. N., & Bishop, M. J., 20...
# 15  Amaral, V., Cabral, H. N., & Bishop, M. J., 20...
# 16  Amaral, V., Cabral, H. N., & Bishop, M. J., 20...
# 17  Amaro, T., Bertocci, I., Queiros, A. M., Raste...
# 18  Amergian, K. E., Beckwith, S., Gfatter, C., Se...
# 19  Amjad, A., Pirzada, J. A. S., Munawwer, R., Na...
#
#                                     DOI DOI_PANGAEA Included/Not included  \
# 0     doi:10.1016/j.heliyon.2020.e04744         NaN          Not included
# 1                 doi:10.1111/jfd.12417         NaN          Not included
# 2                doi:10.3390/min4010145         NaN          Not included
# 3                doi:10.7717/peerj.4377         NaN          Not included
# 4        doi:10.17576/mjas-2019-2306-10         NaN          Not included
# 5      doi:10.1371/journal.pone.0152948         NaN          Not included
# 6      doi:10.1080/10236244.2012.727235         NaN          Not included
# 7           doi:10.1111/1758-2229.12844         NaN          Not included
# 8      doi:10.1016/j.palaeo.2018.06.015         NaN          Not included
# 9           doi:10.5194/bg-13-1037-2016         NaN          Not included
# 10      doi:10.1016/j.jembe.2014.07.001         NaN          Not included
# 11          doi:10.4236/jep.2013.47a008         NaN          Not included
# 12    doi:10.1016/j.aquatox.2016.09.010         NaN          Not included
# 13     doi:10.1371/journal.pone.0035171         NaN          Not included
# 14       doi:10.1016/j.ecss.2011.05.024         NaN          Not included
# 15        doi:10.1007/s10452-011-9385-5         NaN          Not included
# 16       doi:10.1016/j.ecss.2013.11.019         NaN          Not included
# 17  doi:10.1016/j.marpolbul.2018.01.068         NaN          Not included
# 18            doi:10.2113/gsjfr.52.1.60         NaN          Not included
# 19       doi:10.1016/j.rsma.2020.101391         NaN          Not included
#
#               Reason for non inclusion       Country  Year
# 0   < 2 carbonate chemistry parameters  South Africa  2020
# 1   < 2 carbonate chemistry parameters    EU-Austria  2016
# 2   < 2 carbonate chemistry parameters           USA  2014
# 3   < 2 carbonate chemistry parameters   EU-Portugal  2018
# 4   < 2 carbonate chemistry parameters      Malaysia  2019
# 5   < 2 carbonate chemistry parameters    EU-Germany  2016
# 6   < 2 carbonate chemistry parameters     EU-Sweden  2012
# 7   < 2 carbonate chemistry parameters   New Zealand  2020
# 8   < 2 carbonate chemistry parameters         EU-UK  2018
# 9   < 2 carbonate chemistry parameters    EU-Finland  2016
# 10  < 2 carbonate chemistry parameters    EU-Finland  2014
# 11  < 2 carbonate chemistry parameters    EU-Germany  2013
# 12  < 2 carbonate chemistry parameters        Brazil  2016
# 13  < 2 carbonate chemistry parameters        Brazil  2012
# 14  < 2 carbonate chemistry parameters   EU-Portugal  2011
# 15  < 2 carbonate chemistry parameters   EU-Portugal  2012
# 16  < 2 carbonate chemistry parameters     Australia  2014
# 17  < 2 carbonate chemistry parameters     EU-Greece  2018
# 18  < 2 carbonate chemistry parameters           USA  2022
# 19  < 2 carbonate chemistry parameters      Pakistan  2020
