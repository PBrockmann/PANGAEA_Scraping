# %% [markdown]
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)
#
# 2021/10/07
#
# <img align="left" width="50%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" >

# %% [markdown]
# ### Read the Portal of Experimental Ocean Acidification Data
# https://dataportals.pangaea.de/oa-icc/index2.php?

# %% [markdown]
# #### DATA SEARCH
#
# https://wiki.pangaea.de/wiki/Main_Page
#
# The harvested data centers are available through a large, all-containing, public, read-only Elasticsearch node; available at: http://ws.pangaea.de/es/portals/pansimple/_search?pretty

# %%
import json
import urllib
import pandas as pd

# %%
# Extract all articles (citation_date and keyword included)

url = 'http://ws.pangaea.de/es/dataportal-oa-icc/pansimple/_search?size=2000&_source_include=citation_date,keyword'

jsonurl = urllib.request.urlopen(url)
jsonread = json.loads(jsonurl.read())
jsonurl.close()

# %%
# Transform the resulting json to a pandas dataframe

df = pd.DataFrame.from_dict(jsonread['hits']['hits'])
df
# Out:
#           _index      _type             _id  _score  \
# 0     portals_v2  pansimple  PANGAEA.884674     1.0
# 1     portals_v2  pansimple  PANGAEA.771570     1.0
# 2     portals_v2  pansimple  PANGAEA.779703     1.0
# 3     portals_v2  pansimple  PANGAEA.891075     1.0
# 4     portals_v2  pansimple  PANGAEA.885874     1.0
# ...          ...        ...             ...     ...
# 1320  portals_v2  pansimple  PANGAEA.930756     1.0
# 1321  portals_v2  pansimple  PANGAEA.835969     1.0
# 1322  portals_v2  pansimple  PANGAEA.835967     1.0
# 1323  portals_v2  pansimple  PANGAEA.836013     1.0
# 1324  portals_v2  pansimple  PANGAEA.733948     1.0
#
#                                                 _source
# 0     {'citation_date': '2018-01-09', 'keyword': ['A...
# 1     {'citation_date': '2011-11-18', 'keyword': ['A...
# 2     {'citation_date': '2011-04-21', 'keyword': ['B...
# 3     {'citation_date': '2018-06-15', 'keyword': ['A...
# 4     {'citation_date': '2018-02-02', 'keyword': ['B...
# ...                                                 ...
# 1320  {'citation_date': '2021-04-26', 'keyword': ['A...
# 1321  {'citation_date': '2014-09-15', 'keyword': ['A...
# 1322  {'citation_date': '2014-09-15', 'keyword': ['A...
# 1323  {'citation_date': '2013-09-17', 'keyword': ['A...
# 1324  {'citation_date': '2009-02-18', 'keyword': ['B...
#
# [1325 rows x 5 columns]

# %%
# Reorganize _source dictionnary as columns

# Sometimes only {} and not {'keyword: [...]'}
df['citation_date'] = df['_source'].apply(
    lambda x: eval(str(x))['citation_date'] if 'citation_date' in eval(str(x)).keys() else None)
df['keyword'] = df['_source'].apply(
    lambda x: eval(str(x))['keyword'] if 'keyword' in eval(str(x)).keys() else None)

# %%
# Drop unused columns

df.drop(['_score','_type','_index','_source'], axis=1, inplace=True)
df.sort_values(by=['citation_date'])
# Out:
#                  _id citation_date  \
# 421   PANGAEA.755149    1967-12-13
# 392   PANGAEA.717620    1992-06-05
# 138   PANGAEA.717621    1994-06-05
# 1114  PANGAEA.721926    1995-03-01
# 34    PANGAEA.716842    1995-05-30
# ...              ...           ...
# 874   PANGAEA.934128    2021-07-28
# 1301  PANGAEA.934135    2021-07-28
# 653   PANGAEA.935477    2021-09-06
# 639   PANGAEA.936541    2021-09-30
# 656   PANGAEA.936683    2021-10-05
#
#                                                 keyword
# 421   [Calcification/Dissolution, Coast and continen...
# 392   [Benthos, Calcification/Dissolution, Coast and...
# 138   [Benthos, Calcification/Dissolution, Coast and...
# 1114  [Benthos, Calcification/Dissolution, Coast and...
# 34    [Benthos, Calcification/Dissolution, Coast and...
# ...                                                 ...
# 874   [Benthos, Biomass/Abundance/Elemental composit...
# 1301  [Baltic Sea, Biomass/Abundance/Elemental compo...
# 653   [Benthos, Calcification/Dissolution, Clathromo...
# 639   [Animalia, Benthic animals, Benthos, Biomass/A...
# 656   [Animalia, Antarctic, Benthic animals, Benthos...
#
# [1325 rows x 3 columns]

# %%
# Extract all keywords

allKeywordsDB = sorted(df['keyword'].apply(pd.Series).stack().unique())
print(len(allKeywordsDB))
allKeywordsDB
# Out:
# 1131
# ['Abatus cavernosus',
#  'Abra alba',
#  'Abra nitida',
#  'Abra prismatica',
#  'Abra tenuis',
#  'Acanthaster planci',
#  'Acanthochromis polyacanthus',
#  'Acanthopagrus schlegelii',
#  'Acanthophora spicifera',
#  'Acartia bifilosa',
#  'Acartia clausi',
#  'Acartia grani',
#  'Acartia hudsonica',
#  'Acartia sp.',
#  'Acartia tonsa',
#  'Acetabularia acetabulum',
#  'Acid-base regulation',
#  'Acinetospora crinita',
#  'Acipenser baerii',
#  'Acropora cerealis',
#  'Acropora cervicornis',
#  'Acropora digitifera',
#  'Acropora eurystoma',
#  'Acropora formosa',
#  'Acropora horrida',
#  'Acropora hyacinthus',
#  'Acropora intermedia',
#  'Acropora millepora',
#  'Acropora muricata',
#  'Acropora palmata',
#  'Acropora pulchra',
#  'Acropora sp.',
#  'Acropora spicifera',
#  'Acropora tenuis',
#  'Acropora verweyi',
#  'Acropora yongei',
#  'Acrosorium ciliolatum',
#  'Acteon tornatilis',
#  'Adamussium colbecki',
#  'Adelosina longirostra',
#  'Affinetrina gualtieriana',
#  'Agardhiella subulata',
#  'Agaricia agaricites',
#  'Aglaothamnion byssoides',
#  'Aiptasia pulchella',
#  'Akashiwo sanguinea',
#  'Alaria esculenta',
#  'Alcyonidium hirsutum',
#  'Alcyonium coralloides',
#  'Alexandrium fundyense',
#  'Alexandrium ostenfeldii',
#  'Alexandrium sp.',
#  'Alexandrium tamarense',
#  'Alpheus novaezealandiae',
#  'Amansia rhodantha',
#  'Amblyglyphidodon curacao',
#  'Ammonia aomoriensis',
#  'Ammonia beccarii',
#  'Ammonia sp.',
#  'Ammonia tepida',
#  'Ammotium cassis',
#  'Ampelisca brevicornis',
#  'Amphiascoides atopus',
#  'Amphibalanus amphitrite',
#  'Amphibalanus improvisus',
#  'Amphidinium carterae',
#  'Amphiglena mediterranea',
#  'Amphimonhystera sp.',
#  'Amphipneustes lorioli',
#  'Amphipneustes rostratus',
#  'Amphipneustes similis',
#  'Amphiprion melanopus',
#  'Amphiprion percula',
#  'Amphiprion sebae',
#  'Amphiroa anceps',
#  'Amphiroa fragilissima',
#  'Amphiroa rubra',
#  'Amphiroa sp.',
#  'Amphiroa tribulus',
#  'Amphisorus hemprichii',
#  'Amphisorus kudakajimensis',
#  'Amphistegina gibbosa',
#  'Amphistegina lessonii',
#  'Amphistegina radiata',
#  'Amphiura filiformis',
#  'Amphriprion percula',
#  'Anemonia viridis',
#  'Anguilla anguilla',
#  'Animalia',
#  'Annelida',
#  'Anoplopoma fimbria',
#  'Antarctic',
#  'Anthocidaris crassispina',
#  'Aphanizomenon sp.',
#  'Aplysia californica',
#  'Aplysia punctata',
#  'Apoglossum ruscifolium',
#  'Apohyale prevostii',
#  'Aporocidaris eltaniana',
#  'Apostichopus japonicus',
#  'Arachnoides placenta',
#  'Arbacia lixula',
#  'Arbacia punctulata',
#  'Arca inflata Reeve',
#  'Archaias angulatus',
#  'Arctic',
#  'Arctica islandica',
#  'Argopecten irradians',
#  'Argopecten purpuratus',
#  'Argyrosomus japonicus',
#  'Argyrosomus regius',
#  'Armorella sphaerica',
#  'Arthrocardia corymbosa',
#  'Arthrocladia villosa',
#  'Arthropoda',
#  'Asperococcus ensiformis',
#  'Asterias rubens',
#  'Asterigerina carinata',
#  'Asterionella glacialis',
#  'Asterionellopsis glacialis',
#  'Astrangia poculata',
#  'Astroides calycularis',
#  'Atherina presbyter',
#  'Atractoscion nobilis',
#  'Attheya sp.',
#  'Atylus swammerdami',
#  'Aurelia aurita',
#  'Aurelia labiata',
#  'Avrainvillea amadelpha',
#  'Axinella damicornis',
#  'Babylonia japonica',
#  'Bacteria',
#  'Baculogypsina sphaerulata',
#  'Balanophyllia elegans',
#  'Balanophyllia europaea',
#  'Balanus amphitrite',
#  'Balanus amphitriterite',
#  'Balanus improvisus',
#  'Balliella cladoderma',
#  'Baltic Sea',
#  'Bathycoccus sp.',
#  'Bathymodiolus brevior',
#  'Bathyporeia elegans',
#  'Behaviour',
#  'Benthic animals',
#  'Benthos',
#  'Biddulphia biddulphiana',
#  'Biomass/Abundance/Elemental composition',
#  'Bittium spp.',
#  'Bolivina acuminata',
#  'Bolivina acutula',
#  'Bolivina argentea',
#  'Bolivina pseudoplicata',
#  'Bolivina sp.',
#  'Bolivina spinosa',
#  'Bonnemaisonia clavata',
#  'Boreogadus saida',
#  'Bossiella orbigniana',
#  'Bossiella plumosa',
#  'Botryocladia chiajeana',
#  'Botryocladia madagascariensis',
#  'Bottles or small containers/Aquaria (<20 L)',
#  'Brachiopoda',
#  'Brackish waters',
#  'Brissopsis lyrifera',
#  'Bryozoa',
#  'Bryozoa unidentified',
#  'Buccella tenerrima',
#  'Bugula neritina',
#  'Bugula sp.',
#  'Bulimina denudata',
#  'Bulimina marginata',
#  'Bulimina sp.',
#  'Bulla striata',
#  'CO2 vent',
#  'Caberea boryi',
#  'Cacospongia mollior',
#  'Calanus finmarchicus',
#  'Calanus glacialis',
#  'Calanus hyperboreus',
#  'Calanus pacificus',
#  'Calanus spp.',
#  'Calcarina gaudichaudii',
#  'Calcidiscus leptoporus',
#  'Calcidiscus quadriperforatus',
#  'Calcification/Dissolution',
#  'Calliarthron tuberculosum',
#  'Calliblepharis jubata',
#  'Callinectes sapidus',
#  'Callophyllis laciniata',
#  'Calothrix rhizosoleniae',
#  'Calyptraea chinensis',
#  'Cancer magister',
#  'Cancris auricula',
#  'Candida sake',
#  'Caprella laeviuscula',
#  'Caprella mutica',
#  'Caratium lineatum',
#  'Carcharhinus melanopterus',
#  'Carcinus maenas',
#  'Carpomitra costata',
#  'Carybdea xaymacana',
#  'Caryophyllia smithii',
#  'Cassidulina sp.',
#  'Caulerpa prolifera',
#  'Caulerpa racemosa',
#  'Caulerpa serrulata',
#  'Cavolinia inflexa',
#  'Cellana toreuma',
#  'Cellaria salicornioides',
#  'Celleporella cornuta',
#  'Celleporella hyalina',
#  'Centropages tenuiremis',
#  'Centropages typicus',
#  'Centrostephanus rodgersii',
#  'Ceramiaceae unidentified',
#  'Ceramium bertholdii',
#  'Cerastoderma edule',
#  'Cerastoderma glaucum',
#  'Cerataulina pelagica',
#  'Cerataulina planktonica',
#  'Ceratium fusus',
#  'Ceratium lineatum',
#  'Ceratium spp.',
#  'Ceratium tripos',
#  'Cerithium vulgatum',
#  'Chaetoceros affinis',
#  'Chaetoceros criophilus',
#  'Chaetoceros curvisetus',
#  'Chaetoceros debilis',
#  'Chaetoceros muelleri',
#  'Chaetoceros spp.',
#  'Chamelea gallina',
#  'Chara aspera',
#  'Chara horrida',
#  'Chara tomentosa',
#  'Charonia lampas',
#  'Charophyta',
#  'Cheilodipterus quinquelineatus',
#  'Chionoecetes tanneri',
#  'Chlamydomonas reinhardtii',
#  'Chlorella sp.',
#  'Chlorophyta',
#  'Chondrilla nucula',
#  'Chondrosia reniformis',
#  'Chondrus crispus',
#  'Chordata',
#  'Chromis atripectoralis',
#  'Chromista',
#  'Chrysophyrs auratus',
#  'Chrysymenia ventricosa',
#  'Chylocladia verticillata',
#  'Ciona intestinalis',
#  'Cladocora caespitosa',
#  'Cladophora hutchinsiae',
#  'Cladophora pellucida',
#  'Cladophora sp.',
#  'Cladostephus spongiosus',
#  'Clathromorphum compactum',
#  'Clathromorphum nereostratum',
#  'Clathromorphum obtectulum',
#  'Cliona celata',
#  'Cliona orientalis',
#  'Clupea harengus',
#  'Cnidaria',
#  'Coast and continental shelf',
#  'Coccolithus braarudii',
#  'Coccolithus pelagicus',
#  'Codium bursa',
#  'Codium decorticatum',
#  'Coelastrea aspera',
#  'Community composition and diversity',
#  'Concholepas concholepas',
#  'Containers and aquaria (20-1000 L or < 1 m**2)',
#  'Conus marmoreus',
#  'Corallina elongata',
#  'Corallina officinalis',
#  'Corallina sessilis',
#  'Corallina sp.',
#  'Corallina vancouveriensis Yendo',
#  'Corallium rubrum',
#  'Cornuspira involvens',
#  'Corynophlaea flaccida',
#  'Coryphaena hippurus',
#  'Coscinodiscus sp.',
#  'Coscinodiscus wailesii',
#  'Coturnix coturnix',
#  'Crambe crambe',
#  'Crambe tailliezi',
#  'Crangon crangon',
#  'Craspedocarpus ramentaceus',
#  'Crassostrea angulata',
#  'Crassostrea gigas',
#  'Crassostrea hongkongensis',
#  'Crassostrea virginica',
#  'Crella sp.',
#  'Crepidula fornicata',
#  'Crisia sp.',
#  'Crocosphaera watsonii',
#  'Crossaster papposus',
#  'Cryptococcus sp.',
#  'Cryptonemia lomation',
#  'Cryptonemia tuniformis',
#  'Cryptophyta',
#  'Cryptosula pallasiana',
#  'Ctenocidaris gigantea',
#  'Ctenolabrus rupestris',
#  'Cutleria chilosa',
#  'Cutleria monoica',
#  'Cyanobacteria',
#  'Cyanothece sp.',
#  'Cyclina sinensis',
#  'Cyclope neritea',
#  'Cyclope pellucida',
#  'Cylindrotheca closterium',
#  'Cylindrotheca fusiformis',
#  'Cymodoce truncata',
#  'Cymodocea nodosa',
#  'Cymodocea serrulata',
#  'Cyprinodon variegatus',
#  'Cystofilobasidium infirmominiatum',
#  'Cystoseira amentacea',
#  'Cystoseira barbarta',
#  'Cystoseira brachycarpa',
#  'Cystoseira compressa',
#  'Cystoseira corniculata',
#  'Cystoseira crinita',
#  'Cystoseira foeniculacea',
#  'Cystoseira foeniculata',
#  'Cystoseira spinosa',
#  'Cystoseira tamariscifolia',
#  'Cystoseira zosteroides',
#  'Cytophaga sp.',
#  'Dactyliosolen fragilissimus',
#  'Dactyliosolen sp.',
#  'Daitrona sp.',
#  'Danio rerio',
#  'Dascyllus aruanus',
#  'Dasysiphonia japonica',
#  'Debaryomyces hansenii',
#  'Deep-sea',
#  'Dendraster excentricus',
#  'Dendrophyllia cornigera',
#  'Dendropoma petraeum',
#  'Derbesia marina',
#  'Derbesia tenuissima',
#  'Desmarestia aculeata',
#  'Desmarestia anceps',
#  'Desmarestia menziesii',
#  'Desmophyllum dianthus',
#  'Desmophyllum sp.',
#  'Development',
#  'Dicentrarchus labrax',
#  'Dichocoenia stokesii',
#  'Dichotomaria marginata',
#  'Dictyopteris polypodioides',
#  'Dictyota bartayresiana',
#  'Dictyota dichotoma',
#  'Dictyota sp.',
#  'Dilophus fasciola',
#  'Dinobryon balticum',
#  'Diogenes pugilator',
#  'Diopatra neapolitana',
#  'Diplodus sargus',
#  'Diploria labyrinthiformis',
#  'Dischistodus perspicillatus',
#  'Discosphaerina fagi',
#  'Ditylum brightwellii',
#  'Doryteuthis pealeii',
#  'Dosidicus gigas',
#  'Dudresnaya verticillata',
#  'Dumontia incrassata',
#  'Dunaliella salina',
#  'Dunaliella tertiolecta',
#  'Duncanopsammia axifuga',
#  'Dynamene bifida',
#  'Dynamene torelliae',
#  'Echinaster sepositus',
#  'Echinocardium cordatum',
#  'Echinodermata',
#  'Echinometra mathaei',
#  'Echinometra sp.',
#  'Echinometra viridis',
#  'Ecklonia radiata',
#  'Elachista neglecta',
#  'Electra pilosa',
#  'Elminius modestus',
#  'Elphidium advenum',
#  'Elphidium albiumbilicatum',
#  'Elphidium crispum',
#  'Elphidium excavatum',
#  'Elphidium excavatum clavatum',
#  'Elphidium excavatum excavatum',
#  'Elphidium gerthi',
#  'Elphidium incertum',
#  'Elphidium macellum',
#  'Elphidium margaritaceum',
#  'Elphidium sp.',
#  'Elphidium williamsoni',
#  'Emiliania huxleyi',
#  'Ensis siliqua',
#  'Entire community',
#  'Epinephelus bruneus',
#  'Epistomella bradyana',
#  'Eponides sp.',
#  'Ervilia castanea',
#  'Estuary',
#  'Eucampia zoodiacus',
#  'Eucidaris tribuloides',
#  'Eunicea flexuosa',
#  'Eunicea fusca',
#  'Eunicella singularis',
#  'Euphausia krohni',
#  'Euphausia superba',
#  'Eurypon major',
#  'Eurytemora affinis',
#  'Evechinus chloroticus',
#  'Falkenbergia sp.',
#  'Favia fragum',
#  'Favites abdita',
#  'Field experiment',
#  'Field observation',
#  'Flabellia petiolata',
#  'Flexopecten glaber',
#  'Foraminifera',
#  'Forsterygion lapillum',
#  'Fragilariopsis curta',
#  'Fragilariopsis cylindrus',
#  'Fragilariopsis kerguelensis',
#  'Fucus vesicosus',
#  'Fucus vesiculosus',
#  'Fundulus heteroclitus',
#  'Furcellaria lumbricalis',
#  'Gadus morhua',
#  'Galaxaura rugosa',
#  'Galaxea fascicularis',
#  'Galeolaria caespitosa',
#  'Gammarus locusta',
#  'Gasterosteus aculeatus',
#  'Gene expression (incl. proteomics)',
#  'Gephyrocapsa oceanica',
#  'Gibberulus gibberulus gibbosus',
#  'Gillichthys mirabilis',
#  'Globigerina bulloides',
#  'Globigerinella siphonifera',
#  'Globigerinoides ruber',
#  'Globigerinoides sacculifer',
#  'Gloiocladia furcata',
#  'Gloiocladia microspora',
#  'Glycera alba',
#  'Gnathia aureamaculosa',
#  'Gobiusculus flavescens',
#  'Gondogeneia antarctica',
#  'Goniopora sp.',
#  'Gonyaulax sp.',
#  'Gonyaulax spinifera',
#  'Gracillaria salicornia',
#  'Griffithsia genovefae',
#  'Griffithsia opuntioides',
#  'Griffithsia sp.',
#  'Growth/Morphology',
#  'Guehomyces pullulans',
#  'Guinardia flaccida',
#  'Guinardia sp.',
#  'Gymnodinium arcticum',
#  'Gymnodinium spp.',
#  'Gyrodinium fusiforme',
#  'Haematocelis rubens',
#  'Haliclona mediterranea',
#  'Halimeda cuneata',
#  'Halimeda cylindracea',
#  'Halimeda digitata',
#  'Halimeda incrassata',
#  'Halimeda macroloba',
#  'Halimeda minima',
#  'Halimeda opuntia',
#  'Halimeda taenicola',
#  'Halimeda tuna',
#  'Haliotis discus hannai',
#  'Haliotis diversicolor',
#  'Haliotis fulgens',
#  'Haliotis kamtschatkana',
#  'Haliotis rufescens',
#  'Haliotis tuberculata',
#  'Halodule uninervis',
#  'Halodule wrightii',
#  'Halopteris filicina',
#  'Halopteris scoparia',
#  'Halymenia elongata',
#  'Haminoea hydatis',
#  'Hanzawaia nitidula',
#  'Haploblepharus edwardsii',
#  'Haptophyta',
#  'Haraldia lenormandii',
#  'Haynesina depressula',
#  'Hediste diversicolor',
#  'Heliocidaris crassispi',
#  'Heliocidaris erythrogramma',
#  'Hemicentrotus pulcherrimus',
#  'Hemigrapsus sanguineus',
#  'Hemimycale columella',
#  'Heminuera frondosa',
#  'Hemiscyllium ocellatum',
#  'Henricia oculata',
#  'Heterocapsa sp.',
#  'Heterocapsa triquetra',
#  'Heterosigma akashiwo',
#  'Heterostegina antillarum',
#  'Heterostegina depressa',
#  'Heterotrophic prokaryotes',
#  'Heterozostera tasmanica',
#  'Hexadella topsenti',
#  'Hexaplex trunculus',
#  'Hildenbrandia sp.',
#  'Hincksia mitchelliae',
#  'Hippoglossus hippoglossus',
#  'Holothuria forskali',
#  'Holothuria parva',
#  'Holothuria scabra',
#  'Holothuria tubulosa',
#  'Homarus americanus',
#  'Homarus gammarus',
#  'Hyas araneus',
#  'Hydroides crucigera',
#  'Hydroides elegans',
#  'Hydrolithon boreale',
#  'Hydrolithon onkodes',
#  'Hydrolithon reinboldii',
#  'Hydrolithon samoense',
#  'Hydrolithon sp.',
#  'Hyella sp',
#  'Hypnea pannosa',
#  'Idiosepius pygmaeus',
#  'Idotea baltica',
#  'Idotea emarginata',
#  'Immunology/Self-protection',
#  'Indian Ocean',
#  'Inorganic toxins',
#  'Ircinia oros',
#  'Ircinia variabilis',
#  'Irvinea boergesenii',
#  'Isochrysis galbana',
#  'Isognomon alatus',
#  'Isopora cuneata',
#  'Jania rubens',
#  'Jasus lalandii',
#  'Kallymenia feldmannii',
#  'Kallymenia patens',
#  'Kallymenia requienii',
#  'Kallymenia sp.',
#  'Karenia mikimotoi',
#  'Katharina tunicata',
#  'Katodinium glaucum',
#  'Kondoa malvinella',
#  'Laboratory experiment',
#  'Laboratory strains',
#  'Labroides dimidiatus',
#  'Lacuna vincta',
#  'Laevipeneroplis bradyi',
#  'Lagena sp.',
#  'Laminaria hyperborea',
#  'Laminaria rodriguezii',
#  'Laminaria solidungula',
#  'Larimichthys crocea',
#  'Laternula elliptica',
#  'Lates calcarifer',
#  'Laurencia sp.',
#  'Leathesia mucosa',
#  'Lekanesphaera monodi',
#  'Leptastrea purpurea',
#  'Leptochiton asellus',
#  'Leptofauchea coralligena',
#  'Leptopsammia pruvoti',
#  'Leucoraja erinacea',
#  'Leucosporidium scottii',
#  'Leuresthes tenuis',
#  'Light',
#  'Limacina helicina',
#  'Limacina helicina antarctica',
#  'Limacina retroversa',
#  'Lingulodinium polyedrum',
#  'Liocarcinus arcuatus',
#  'Liothyrella uva',
#  'Lithophyllum cabiochae',
#  'Lithophyllum congestum',
#  'Lithophyllum flavescens',
#  'Lithophyllum incrustans',
#  'Lithophyllum kotschyanum',
#  'Lithophyllum prototypum',
#  'Lithophyllum sp.',
#  'Lithophyllum stictaeforme',
#  'Lithothamnion corallioides',
#  'Lithothamnion glaciale',
#  'Lithothamnion sp.',
#  'Lithothamnion valens',
#  'Litiorina littorea',
#  'Litopenaeus vannamei',
#  'Littorina littorea',
#  'Littorina obtusata',
#  'Lobatula lobatula',
#  'Lobophora papenfussii',
#  'Lobophora variegata',
#  'Lobophytum pauciflorum',
#  'Lohmaniella oviformis',
#  'Loligo vulgaris',
#  'Lomentaria australis',
#  'Lomentaria chylocladiella',
#  'Lomentaria ercegovicii',
#  'Lomentaria subdichotoma',
#  'Lophelia pertusa',
#  'Loripes lacteus',
#  'Loxechinus albus',
#  'Loxostomum pseudoberyrichi',
#  'Luidia clathrata',
#  'Lutraria lutraria',
#  'Lysidice collaris',
#  'Lysidice ninetta',
#  'Lytechinus pictus',
#  'Lytechinus variegatus',
#  'Macoma balthica',
#  'Macro-nutrients',
#  'Macroalgae',
#  'Macrocystis pyrifera',
#  'Madracis mirabilis',
#  'Madrepora oculata',
#  'Magallana angulata',
#  'Magallana hongkongensis',
#  'Magelona johnstoni',
#  'Magelona mirabilis',
#  'Malacobelemnon daytoni',
#  'Margarella antarctica',
#  'Marginopora rossi',
#  'Marginopora vertebralis',
#  'Massilina gualtieriana',
#  'Mastigocoleus testarum',
#  'Mediterranean Sea',
#  'Melita palmata',
#  'Menidia beryllina',
#  'Menidia menidia',
#  'Menippe mercenaria',
#  'Mercenaria mercenaria',
#  'Meredithia microphylla',
#  'Meretrix meretrix',
#  'Mesalia mesal',
#  'Mesocentrotus franciscanus',
#  'Mesocosm or benthocosm',
#  'Mesodinium rubrum',
#  'Mesophyllum alternans',
#  'Mesophyllum expansum',
#  'Metacarcinus magister',
#  'Metapenaeus monoceros',
#  'Micro-nutrients',
#  'Microciona cf toxitenuis',
#  'Microglena sp.',
#  'Micromonas pusilla',
#  'Miliammina fusca',
#  'Miliola sp.',
#  'Miliolinella sp.',
#  'Miliolinella subrotunda',
#  'Mimachlamys asperrima',
#  'Mimosella gracilis',
#  'Mimosella verticillata',
#  'Mollusca',
#  'Montastraea cavernosa',
#  'Montipora aequituberculata',
#  'Montipora capitata',
#  'Montipora digitata',
#  'Montipora flabellata',
#  'Montipora monasteriata',
#  'Montipora patula',
#  'Mopalia muscosa',
#  'Mortality/Survival',
#  'Musculista senhousia',
#  'Mya arenaria',
#  'Mycale grandis',
#  'Myriapora truncata',
#  'Myriogramme tristromatica',
#  'Myriotrichia adriatica',
#  'Mytilus californianus',
#  'Mytilus chilensis',
#  'Mytilus coruscus',
#  'Mytilus edulis',
#  'Mytilus galloprovincialis',
#  'Mytilus trossulus',
#  'Myzozoa',
#  'Nacella concinna',
#  'Naso elegans',
#  'Nassarius conoidalis',
#  'Nassarius corniculus',
#  'Nassarius cuvieri',
#  'Nassarius festivus',
#  'Nassarius incrassatus',
#  'Nassarius nitidus',
#  'Nassarius pfeifferi',
#  'Nassarius pygmaeus',
#  'Nassarius reticulatus',
#  'Navicula granii',
#  'Navicula sp.',
#  'Navicula spp.',
#  'Navicula vanhoeffenii',
#  'Necora puber',
#  'Nekton',
#  'Neodenticula seminae',
#  'Neogloboquadrina incompta',
#  'Neogloboquadrina pachyderma',
#  'Neogoniolithon',
#  'Neogoniolithon brassica-florida',
#  'Neogoniolithon frutescens',
#  'Neogoniolithon mamillosum',
#  'Neogoniolithon sp.',
#  'Neogoniolithon spectabile',
#  'Neogonodactylus bredini',
#  'Neomonospora pedicellata var. tenuis',
#  'Neosiphonia harveyi',
#  'Nephtys cirrosa',
#  'Nephtys hombergii',
#  'Neurocaulon foliosum',
#  'Nitophyllum flabellatum',
#  'Nitophyllum punctatum',
#  'Nitzschia closterium',
#  'Nitzschia lecointei',
#  'Nodularia spumigena',
#  'Nonionella basispinata',
#  'Nonionella sp.',
#  'North Atlantic',
#  'North Pacific',
#  'Not applicable',
#  'Notocidaris gaussensis',
#  'Notoclinops segmentatus',
#  'Notoclinops yaldwyni',
#  'Notothenia rossii',
#  'Nucella lapillus',
#  'Nucella ostrina',
#  'Nucula nucleus',
#  'Nucula sulcata',
#  'Nyctiphanes couchii',
#  'Ochrophyta',
#  'Ochrosphaera neapolitana',
#  'Oculina arbuscula',
#  'Oculina patagonica',
#  'Odontaster validus',
#  'Odontella weissflogii',
#  'Oikopleura dioica',
#  'Oithona davisae',
#  'Oithona similis',
#  'Oligochaeta sp.',
#  'Oncorhynchus gorbuscha',
#  'Oncorhynchus mykiss',
#  'Open ocean',
#  'Operculina ammonoides',
#  'Ophiocomina nigra',
#  'Ophiothrix fragilis',
#  'Ophryotrocha japonica',
#  'Ophryotrocha labronica',
#  'Ophryotrocha robusta',
#  'Orbicella faveolata',
#  'Orbulina universa',
#  'Oreochromis mossambicus',
#  'Organic toxins',
#  'Oryzias melastigma',
#  'Oscillatoria spp',
#  'Osilinus turbinatus',
#  'Osmundea pelagosae',
#  'Ostorhinchus cyanosoma',
#  'Ostorhinchus doederleini',
#  'Ostrea chilensis',
#  'Ostrea edulis',
#  'Ostrea lurida',
#  'Ostreobium spp',
#  'Ostreococcus sp.',
#  'Ostreococcus tauri',
#  'Other',
#  'Other metabolic rates',
#  'Other studied parameter or process',
#  'Oxygen',
#  'Pachygrapsus marmoratus',
#  'Padina australis',
#  'Padina pavonica',
#  'Padina spp.',
#  'Pagurus bernhardus',
#  'Pagurus sp.',
#  'Pagurus tanneri',
#  'Palaemon intermedius',
#  'Palaemon serenus',
#  'Palmaria palmata',
#  'Pandalus borealis',
#  'Panopeus herbstii',
#  'Paphia aurea',
#  'Paphia rhomboides',
#  'Paphia undulate',
#  'Parablennius laticlavius',
#  'Paracentrotus lividus',
#  'Paradexamine fissicauda',
#  'Parafavella spp.',
#  'Paralichthys dentatus',
#  'Paralichthys olivaceus',
#  'Parazoanthus axinellae',
#  'Parorchis sp.',
#  'Parvicardium exiguum',
#  'Patella caerulea',
#  'Patella rustica',
#  'Patella vulgata',
#  'Patinopecten yessoensis',
#  'Patiriella regularis',
#  'Pavona cactus',
#  'Pecten maximus',
#  'Pelagos',
#  'Penaeus plebejus',
#  'Peneroplis pertusus',
#  'Peneroplis planatus',
#  'Peneroplis sp.',
#  'Pentapora fascialis',
#  'Peringia ulvae',
#  'Perna canaliculus',
#  'Perna perna',
#  'Perumytilus purpuratus',
#  'Petalonia sp.',
#  'Petrolisthes cinctipes',
#  'Petrosia ficiformis',
#  'Peyssonnelia crispata',
#  'Peyssonnelia dubyi',
#  'Peyssonnelia harveyana',
#  'Peyssonnelia inamoena',
#  'Peyssonnelia rosa-marina',
#  'Peyssonnelia sp.',
#  'Peyssonnelia squamaria',
#  'Phaedactylum tricornutum',
#  'Phaeocystis antarctica',
#  'Phaeocystis globosa',
#  'Phaeocystis pouchetii',
#  'Phaeodactylum tricornutum',
#  'Pherusella tubulosa',
#  'Philophthalmus sp.',
#  'Pholas dactylus',
#  'Phorbas ficticius',
#  'Phorbas fictitius',
#  'Phorbas tenacior',
#  'Phorcus sauciatus',
#  'Phyllacanthus imperialis',
#  'Phyllariopsis brevipes',
#  'Phyllophora crispa',
#  'Phymatolithon calcareum',
#  'Phymatolithon lusitanicum',
#  'Phytoplankton',
#  'Pileolina patelliformis',
#  'Pinna nobilis',
#  'Planorbulina acervalis',
#  'Plantae',
#  'Platichthys flesus',
#  'Platygyra contorta',
#  'Platyhelminthes',
#  'Platynereis dumerilii',
#  'Plectonema terebrans',
#  'Plectropomus leopardus',
#  'Plesiastrea versipora',
#  'Pleurochrysis carterae',
#  'Pleurochrysis placolithoides',
#  'Plocamium angustum',
#  'Plocamium cartilagineum',
#  'Pneophyllum sp.',
#  'Pocillopora acuta',
#  'Pocillopora damicornis',
#  'Pocillopora eydouxi',
#  'Pocillopora meandrina',
#  'Pocillopora verrucosa',
#  'Polar',
#  'Polyophthalmus pictus',
#  'Polysiphonia elongella',
#  'Polysiphonia flocculosa',
#  'Polysiphonia fucoides',
#  'Polysiphonia subulifera',
#  'Pomacentrus amboinensis',
#  'Pomacentrus chrysurus',
#  'Pomacentrus moluccensis',
#  'Pomacentrus nagasakiensis',
#  'Pomacentrus wardi',
#  'Pomatoschistus pictus',
#  'Porella cervicornis',
#  'Porifera',
#  'Porifera unidentified',
#  'Porites astreoides',
#  'Porites compressa',
#  'Porites cylindrica',
#  'Porites divaricata',
#  'Porites evermanni',
#  'Porites irregularis',
#  'Porites lobata',
#  'Porites lutea',
#  'Porites murrayensis',
#  'Porites panamensis',
#  'Porites porites',
#  'Porites rus',
#  'Porites sp.',
#  'Porolithon onkodes',
#  'Porphyra purpurea',
#  'Posidonia oceanica',
#  'Potamogeton perfoliatus',
#  'Praunus flexuosus',
#  'Primary production/Photosynthesis',
#  'Proboscia alata',
#  'Proboscia truncata',
#  'Prochlorococcus sp.',
#  'Prorocentrum micans',
#  'Prorocentrum minimum',
#  'Prorocentrum spp.',
#  'Proteobacteria',
#  'Protoceratium reticulatum',
#  'Psammechinus miliaris',
#  'Psammocora profundacella',
#  'Psetta maxima',
#  'Pseudo-nitzschia fraudulenta',
#  'Pseudo-nitzschia pseudodelicatissima',
#  'Pseudo-nitzschia spp.',
#  'Pseudo-nitzschia subcurvata',
#  'Pseudochlorodesmis furcellata',
#  'Pseudochromis fuscus',
#  'Pseudodiploria clivosa',
#  'Pseudodiploria strigosa',
#  'Pseudonitzschia delicatissima',
#  'Pseudonitzschia sp.',
#  'Pseudonitzschia turgiduloides',
#  'Pseudopleuronectes americanus',
#  'Pseudotriloculina sp.',
#  'Pterothamnion crispum',
#  'Pycnoclavella sp.',
#  'Pyramimonas sp.',
#  'Pyropia yezoensis',
#  'Quinquelloculina sp.',
#  'Quinqueloculina annectens',
#  'Quinqueloculina auberiana',
#  'Quinqueloculina bosciana',
#  'Quinqueloculina sp.',
#  'Quinqueloculina stelligera',
#  'Ramularia pratensis var. pratensis',
#  'Red Sea',
#  'Reophax dentaliniformis',
#  'Reophax sp.',
#  'Reproduction',
#  'Respiration',
#  'Reteporella sp.',
#  'Rhizosolenia setigera',
#  'Rhizosolenia sp.',
#  'Rhizosolenia spp.',
#  'Rhodomonas sp.',
#  'Rhodomos Sali',
#  'Rhodophyllis divaricata',
#  'Rhodophyllis gunnii',
#  'Rhodophyllis strafforelloi',
#  'Rhodophyta',
#  'Rhodotorula mucilaginosa',
#  'Rhodymenia sp.',
#  'Rimostrombidium sp.',
#  'Rissoa monodonta',
#  'Rocky-shore community',
#  'Rodriguezella pinnata',
#  'Rosalina globularis',
#  'Rosalina sp.',
#  'Ruditapes decussatus',
#  'Ruditapes philippinarum',
#  'Ruppia maritima',
#  'Sabella spallanzanii',
#  'Saccharina latissima',
#  'Saccostrea glomerata',
#  'Salinity',
#  'Salmo salar',
#  'Salmo trutta',
#  'Sarcophyton elegans',
#  'Sarcophyton sp.',
#  'Sarcotragus spinosulus',
#  'Sargassum muticum',
#  'Sargassum vulgare',
#  'Savignyella lafontii',
#  'Scalarispongia scalaris',
#  'Scapharca broughtonii',
#  'Schizopera knabeni',
#  'Schizoseris sp.',
#  'Sciaenops ocellatus',
#  'Scoloplos armiger',
#  'Scrippsiella trochoidea',
#  'Scrobicularia plana',
#  'Scyliorhinus canicula',
#  'Scyphosphaera apsteinii',
#  'Seagrass',
#  'Sebastes diploproa',
#  'Sebastes mystinus',
#  'Sebdenia rodrigueziana',
#  'Semibalanus balanoides',
#  'Sepia officilis',
#  'Sepia officinalis',
#  'Sepioteuthis lessoniana',
#  'Seriatopora caliendrum',
#  'Seriatopora hystrix',
#  'Seriola lalandi',
#  'Siderastrea radians',
#  'Siderastrea siderea',
#  'Sigalion mathildae',
#  'Simplaria sp.',
#  'Single species',
#  'Sinonovacula constricta',
#  'Sinularia sp.',
#  ...]

# %%
# Find number of datasets for each keyword for the 2 periods

dfreq = pd.DataFrame()
year = 2015

for k in allKeywordsDB:
    s_total = df[df['keyword'].apply(lambda x: bool(set(x) & set([k]) if x != None else []))]
    s_period1 = s_total[s_total['citation_date'].between('1950-01-01', str(year-1)+'-12-31')]
    s_period2 = s_total[s_total['citation_date'].between(str(year)+'-01-01', '2030-12-31')]
    dfreq = dfreq.append({ 'keyword': k, 
                    'before ' + str(year): len(s_period1), 
                    'after ' + str(year):  len(s_period2)}, 
                    ignore_index=True)

# %%
# Specify int type

dfreq = dfreq.astype({ 'before ' + str(year): int, 
            'after ' + str(year):  int
          })

# %%
# Save to CSV file

dfreq.to_csv('OA-ICC_keywords_before_after_2015.csv', index=False)

# %%
dfreq
# Out:
#                  keyword  before 2015  after 2015
# 0      Abatus cavernosus            0           1
# 1              Abra alba            1           0
# 2            Abra nitida            1           0
# 3        Abra prismatica            1           0
# 4            Abra tenuis            1           0
# ...                  ...          ...         ...
# 1126  Zostera capricorni            0           1
# 1127    Zostera japonica            0           1
# 1128      Zostera marina            0           6
# 1129    Zostera muelleri            1           0
# 1130      Zostera noltii            1           1
#
# [1131 rows x 3 columns]
