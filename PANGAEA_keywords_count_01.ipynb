# %% [markdown]
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)
#
#  * 2022/06/28 - updated
#  * 2021/12/13 - initial revision
#
# <img align="left" width="50%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" >

# %% [markdown]
# ### Read the Portal of Experimental Ocean Acidification Data
# https://dataportals.pangaea.de/oa-icc/index2.php?

# %% [markdown]
# #### DATA SEARCH
#
# https://wiki.pangaea.de/wiki/Main_Page
#
# The harvested data centers are available through a large, all-containing, public, read-only Elasticsearch node; available at: http://ws.pangaea.de/es/portals/pansimple/_search?pretty

# %%
import json
import urllib
import pandas as pd

# %%
# Extract all articles (citation_date and keyword included)

url = 'http://ws.pangaea.de/es/dataportal-oa-icc/pansimple/_search?size=2000&_source_include=citation_date,keyword'

jsonurl = urllib.request.urlopen(url)
jsonread = json.loads(jsonurl.read())
jsonurl.close()

# %%
# Transform the resulting json to a pandas dataframe

df = pd.DataFrame.from_dict(jsonread['hits']['hits'])
df
# Out:
#           _index      _type             _id  _score  \
# 0     portals_v1  pansimple  PANGAEA.754779     1.0
# 1     portals_v1  pansimple  PANGAEA.752286     1.0
# 2     portals_v1  pansimple  PANGAEA.891075     1.0
# 3     portals_v1  pansimple  PANGAEA.771570     1.0
# 4     portals_v1  pansimple  PANGAEA.763988     1.0
# ...          ...        ...             ...     ...
# 1479  portals_v1  pansimple  PANGAEA.943395     1.0
# 1480  portals_v1  pansimple  PANGAEA.952656     1.0
# 1481  portals_v1  pansimple  PANGAEA.770067     1.0
# 1482  portals_v1  pansimple  PANGAEA.960042     1.0
# 1483  portals_v1  pansimple  PANGAEA.832340     1.0
#
#                                                 _source
# 0     {'citation_date': '2010-12-07', 'keyword': ['A...
# 1     {'citation_date': '2010-11-02', 'keyword': ['A...
# 2     {'citation_date': '2018-06-15', 'keyword': ['A...
# 3     {'citation_date': '2011-11-18', 'keyword': ['A...
# 4     {'citation_date': '2011-08-19', 'keyword': ['A...
# ...                                                 ...
# 1479  {'keyword': ['Animalia', 'Arthropoda', 'Behavi...
# 1480  {'citation_date': '2022-12-20', 'keyword': ['A...
# 1481  {'citation_date': '2011-09-23', 'keyword': ['B...
# 1482  {'keyword': ['Benthos', 'Calcification/Dissolu...
# 1483  {'citation_date': '2014-05-07', 'keyword': ['C...
#
# [1484 rows x 5 columns]

# %%
# Reorganize _source dictionnary as columns

# Sometimes only {} and not {'keyword: [...]'}
df['citation_date'] = df['_source'].apply(
    lambda x: eval(str(x))['citation_date'] if 'citation_date' in eval(str(x)).keys() else None)
df['keyword'] = df['_source'].apply(
    lambda x: eval(str(x))['keyword'] if 'keyword' in eval(str(x)).keys() else None)

# Force to be a list (not the case when only 1 keyword)
df['keyword'] = df['keyword'].apply(lambda x: [x] if type(x) is not list else x)

# %%
# Drop unused columns

df.drop(['_score','_type','_index','_source'], axis=1, inplace=True)
df.sort_values(by=['citation_date'])
# Out:
#                  _id citation_date  \
# 153   PANGAEA.721856    2009-06-23
# 1112  PANGAEA.726862    2009-08-27
# 813   PANGAEA.726856    2009-08-27
# 160   PANGAEA.727545    2009-09-16
# 191   PANGAEA.728723    2009-10-23
# ...              ...           ...
# 1476  PANGAEA.942326          None
# 1477  PANGAEA.934173          None
# 1478  PANGAEA.933580          None
# 1479  PANGAEA.943395          None
# 1482  PANGAEA.960042          None
#
#                                                 keyword
# 153   [Benthos, Calcification/Dissolution, Coast and...
# 1112  [Bacteria, Biomass/Abundance/Elemental composi...
# 813   [Animalia, Arctic, Bottles or small containers...
# 160   [Benthos, Calcification/Dissolution, Coast and...
# 191   [Animalia, Atractoscion nobilis, Behaviour, Bi...
# ...                                                 ...
# 1476  [Animalia, Benthic animals, Benthos, Bottles o...
# 1477  [Animalia, Bottles or small containers/Aquaria...
# 1478  [Bottles or small containers/Aquaria (<20 L), ...
# 1479  [Animalia, Arthropoda, Behaviour, Bottles or s...
# 1482  [Benthos, Calcification/Dissolution, Coast and...
#
# [1484 rows x 3 columns]

# %%
# Extract all keywords

allKeywordsDB = sorted(df['keyword'].apply(pd.Series).stack().unique())
print(len(allKeywordsDB))
allKeywordsDB
# Out:
# 1242
# ['Abatus cavernosus',
#  'Abra alba',
#  'Abra nitida',
#  'Abra prismatica',
#  'Abra tenuis',
#  'Abudefduf vaigiensis',
#  'Acanthaster planci',
#  'Acanthochromis polyacanthus',
#  'Acanthopagrus schlegelii',
#  'Acanthophora spicifera',
#  'Acartia bifilosa',
#  'Acartia clausi',
#  'Acartia grani',
#  'Acartia hudsonica',
#  'Acartia pacifica',
#  'Acartia sp.',
#  'Acartia tonsa',
#  'Acetabularia acetabulum',
#  'Acid-base regulation',
#  'Acinetospora crinita',
#  'Acipenser baerii',
#  'Acropora cerealis',
#  'Acropora cervicornis',
#  'Acropora cytherea',
#  'Acropora digitifera',
#  'Acropora eurystoma',
#  'Acropora formosa',
#  'Acropora horrida',
#  'Acropora humilis',
#  'Acropora hyacinthus',
#  'Acropora intermedia',
#  'Acropora millepora',
#  'Acropora muricata',
#  'Acropora palmata',
#  'Acropora pulchra',
#  'Acropora samoensis',
#  'Acropora solitaryensis',
#  'Acropora sp.',
#  'Acropora spicifera',
#  'Acropora tenuis',
#  'Acropora verweyi',
#  'Acropora yongei',
#  'Acrosorium ciliolatum',
#  'Acteon tornatilis',
#  'Adamussium colbecki',
#  'Adelosina longirostra',
#  'Affinetrina gualtieriana',
#  'Agardhiella subulata',
#  'Agaricia agaricites',
#  'Aglaothamnion byssoides',
#  'Aiptasia pulchella',
#  'Akashiwo sanguinea',
#  'Alaria esculenta',
#  'Alcyonidium hirsutum',
#  'Alcyonium coralloides',
#  'Alexandrium fundyense',
#  'Alexandrium minutum',
#  'Alexandrium ostenfeldii',
#  'Alexandrium sp.',
#  'Alexandrium tamarense',
#  'Alpheus novaezealandiae',
#  'Alteromonas sp.',
#  'Amansia rhodantha',
#  'Amblyglyphidodon curacao',
#  'Amblyraja radiata',
#  'Ammonia aomoriensis',
#  'Ammonia beccarii',
#  'Ammonia confertitesta',
#  'Ammonia sp.',
#  'Ammonia tepida',
#  'Ammotium cassis',
#  'Ampelisca brevicornis',
#  'Amphiascoides atopus',
#  'Amphibalanus amphitrite',
#  'Amphibalanus improvisus',
#  'Amphidinium carterae',
#  'Amphiglena mediterranea',
#  'Amphimonhystera sp.',
#  'Amphipneustes lorioli',
#  'Amphipneustes rostratus',
#  'Amphipneustes similis',
#  'Amphiprion melanopus',
#  'Amphiprion percula',
#  'Amphiprion sebae',
#  'Amphiroa anceps',
#  'Amphiroa fragilissima',
#  'Amphiroa gracilis',
#  'Amphiroa rubra',
#  'Amphiroa sp.',
#  'Amphiroa tribulus',
#  'Amphisorus hemprichii',
#  'Amphisorus kudakajimensis',
#  'Amphistegina gibbosa',
#  'Amphistegina lessonii',
#  'Amphistegina radiata',
#  'Amphiura filiformis',
#  'Amphriprion percula',
#  'Anemonia viridis',
#  'Anguilla anguilla',
#  'Animalia',
#  'Annelida',
#  'Anoplopoma fimbria',
#  'Antarctic',
#  'Anthocidaris crassispina',
#  'Aphanizomenon sp.',
#  'Aplysia californica',
#  'Aplysia punctata',
#  'Apoglossum ruscifolium',
#  'Apohyale prevostii',
#  'Aporocidaris eltaniana',
#  'Apostichopus japonicus',
#  'Arbacia lixula',
#  'Arbacia punctulata',
#  'Arca inflata Reeve',
#  'Archaias angulatus',
#  'Arctic',
#  'Arctica islandica',
#  'Argopecten irradians',
#  'Argopecten purpuratus',
#  'Argyrosomus japonicus',
#  'Argyrosomus regius',
#  'Armorella sphaerica',
#  'Artemia franciscana',
#  'Arthrocardia corymbosa',
#  'Arthrocladia villosa',
#  'Arthropoda',
#  'Asperococcus ensiformis',
#  'Asterias rubens',
#  'Asterigerina carinata',
#  'Asterionella glacialis',
#  'Asterionellopsis glacialis',
#  'Astrangia poculata',
#  'Astroides calycularis',
#  'Atherina presbyter',
#  'Atlanta ariejansseni',
#  'Atractoscion nobilis',
#  'Attheya sp.',
#  'Atylus swammerdami',
#  'Atypichthys strigatus',
#  'Aulacomya atra',
#  'Aurelia aurita',
#  'Aurelia labiata',
#  'Avrainvillea amadelpha',
#  'Axinella damicornis',
#  'Azumapecten farreri',
#  'Babylonia japonica',
#  'Bacteria',
#  'Baculogypsina sphaerulata',
#  'Balanophyllia elegans',
#  'Balanophyllia europaea',
#  'Balanus amphitrite',
#  'Balanus amphitriterite',
#  'Balanus improvisus',
#  'Balliella cladoderma',
#  'Baltic Sea',
#  'Bathycoccus sp.',
#  'Bathymodiolus brevior',
#  'Bathyporeia elegans',
#  'Behaviour',
#  'Benthic animals',
#  'Benthos',
#  'Biddulphia biddulphiana',
#  'Biomass/Abundance/Elemental composition',
#  'Bittium sp.',
#  'Bolivina acuminata',
#  'Bolivina acutula',
#  'Bolivina argentea',
#  'Bolivina pseudoplicata',
#  'Bolivina sp.',
#  'Bolivina spinosa',
#  'Bonnemaisonia clavata',
#  'Boreogadus saida',
#  'Bossiella orbigniana',
#  'Bossiella plumosa',
#  'Botryocladia chiajeana',
#  'Botryocladia madagascariensis',
#  'Bottles or small containers/Aquaria (<20 L)',
#  'Brachiopoda',
#  'Brackish waters',
#  'Brissopsis lyrifera',
#  'Bryozoa',
#  'Bryozoa unidentified',
#  'Buccella tenerrima',
#  'Bugula neritina',
#  'Bugula sp.',
#  'Bulimina denudata',
#  'Bulimina marginata',
#  'Bulimina sp.',
#  'Bulla striata',
#  'CO2 vent',
#  'Caberea boryi',
#  'Cacospongia mollior',
#  'Calanus finmarchicus',
#  'Calanus glacialis',
#  'Calanus hyperboreus',
#  'Calanus pacificus',
#  'Calanus sp.',
#  'Calcarina gaudichaudii',
#  'Calcidiscus leptoporus',
#  'Calcidiscus quadriperforatus',
#  'Calcification/Dissolution',
#  'Calliarthron tuberculosum',
#  'Calliblepharis jubata',
#  'Callinectes sapidus',
#  'Callophyllis laciniata',
#  'Calothrix rhizosoleniae',
#  'Calyptraea chinensis',
#  'Cancer magister',
#  'Cancris auricula',
#  'Candida sake',
#  'Caprella laeviuscula',
#  'Caprella mutica',
#  'Carcharhinus melanopterus',
#  'Carcinus maenas',
#  'Carpomitra costata',
#  'Carybdea xaymacana',
#  'Caryophyllia smithii',
#  'Cassidulina laevigata',
#  'Cassidulina sp.',
#  'Cassiopeia sp.',
#  'Caulerpa prolifera',
#  'Caulerpa racemosa',
#  'Caulerpa serrulata',
#  'Cavolinia inflexa',
#  'Cellana toreuma',
#  'Cellaria salicornioides',
#  'Celleporella cornuta',
#  'Celleporella hyalina',
#  'Centropages tenuiremis',
#  'Centropages typicus',
#  'Centropristis striata',
#  'Centrostephanus rodgersii',
#  'Ceramiaceae unidentified',
#  'Ceramium bertholdii',
#  'Cerastoderma edule',
#  'Cerastoderma glaucum',
#  'Cerataulina pelagica',
#  'Cerataulina planktonica',
#  'Ceratium fusus',
#  'Ceratium lineatum',
#  'Ceratium sp.',
#  'Ceratium tripos',
#  'Cerithium vulgatum',
#  'Chaetoceros affinis',
#  'Chaetoceros criophilus',
#  'Chaetoceros curvisetus',
#  'Chaetoceros debilis',
#  'Chaetoceros muelleri',
#  'Chaetoceros sp.',
#  'Chamelea gallina',
#  'Chara aspera',
#  'Chara horrida',
#  'Chara tomentosa',
#  'Charonia lampas',
#  'Charophyta',
#  'Cheilodipterus quinquelineatus',
#  'Chionoecetes bairdi',
#  'Chionoecetes tanneri',
#  'Chlamydomonas reinhardtii',
#  'Chlamys islandica',
#  'Chlorella sp.',
#  'Chlorophyta',
#  'Chondrilla nucula',
#  'Chondrosia reniformis',
#  'Chondrus crispus',
#  'Chordata',
#  'Choromytilus meridionalis',
#  'Chromis atripectoralis',
#  'Chromis punctipinnis',
#  'Chromista',
#  'Chrysophyrs auratus',
#  'Chrysymenia ventricosa',
#  'Chylocladia verticillata',
#  'Ciona intestinalis',
#  'Cladocora caespitosa',
#  'Cladophora hutchinsiae',
#  'Cladophora pellucida',
#  'Cladophora sp.',
#  'Cladostephus spongiosus',
#  'Clathromorphum compactum',
#  'Clathromorphum nereostratum',
#  'Clathromorphum obtectulum',
#  'Clio pyramidata',
#  'Cliona celata',
#  'Cliona orientalis',
#  'Cliona varians',
#  'Cliothosa delitrix',
#  'Clupea harengus',
#  'Clupea pallasii',
#  'Cnidaria',
#  'Coast and continental shelf',
#  'Coccolithus braarudii',
#  'Coccolithus pelagicus',
#  'Codium bursa',
#  'Codium decorticatum',
#  'Coelastrea aspera',
#  'Columbella rustica',
#  'Community composition and diversity',
#  'Concholepas concholepas',
#  'Containers and aquaria (20-1000 L or < 1 m**2)',
#  'Conus marmoreus',
#  'Copepoda',
#  'Corallina elongata',
#  'Corallina officinalis',
#  'Corallina sessilis',
#  'Corallina sp.',
#  'Corallina vancouveriensis Yendo',
#  'Corallium rubrum',
#  'Cornuspira involvens',
#  'Corophium volutator',
#  'Corynophlaea flaccida',
#  'Coryphaena hippurus',
#  'Coscinodiscus sp.',
#  'Coscinodiscus wailesii',
#  'Coturnix coturnix',
#  'Cotylorhiza tuberculata',
#  'Crambe crambe',
#  'Crambe tailliezi',
#  'Crangon crangon',
#  'Craspedocarpus ramentaceus',
#  'Crassostrea angulata',
#  'Crassostrea brasiliana',
#  'Crassostrea gigas',
#  'Crassostrea hongkongensis',
#  'Crassostrea virginica',
#  'Crella sp.',
#  'Crepidula fornicata',
#  'Crisia sp.',
#  'Crocosphaera watsonii',
#  'Crossaster papposus',
#  'Crusticorallina adhaerens',
#  'Crusticorallina muricata',
#  'Crusticorallina painei',
#  'Cryptococcus sp.',
#  'Cryptonemia lomation',
#  'Cryptonemia tuniformis',
#  'Cryptophyta',
#  'Cryptosula pallasiana',
#  'Ctenocidaris gigantea',
#  'Ctenolabrus rupestris',
#  'Cutleria chilosa',
#  'Cutleria monoica',
#  'Cuvierina atlantica',
#  'Cuvierina pacifica',
#  'Cyanobacteria',
#  'Cyanothece sp.',
#  'Cyclina sinensis',
#  'Cyclope neritea',
#  'Cyclope pellucida',
#  'Cylindrotheca closterium',
#  'Cylindrotheca fusiformis',
#  'Cymodoce truncata',
#  'Cymodocea nodosa',
#  'Cymodocea serrulata',
#  'Cyprinodon variegatus',
#  'Cystofilobasidium infirmominiatum',
#  'Cystoseira amentacea',
#  'Cystoseira barbarta',
#  'Cystoseira brachycarpa',
#  'Cystoseira compressa',
#  'Cystoseira corniculata',
#  'Cystoseira crinita',
#  'Cystoseira foeniculacea',
#  'Cystoseira foeniculata',
#  'Cystoseira spinosa',
#  'Cystoseira tamariscifolia',
#  'Cystoseira zosteroides',
#  'Cytophaga sp.',
#  'Dactyliosolen fragilissimus',
#  'Dactyliosolen sp.',
#  'Daitrona sp.',
#  'Danio rerio',
#  'Dascyllus aruanus',
#  'Dasysiphonia japonica',
#  'Debaryomyces hansenii',
#  'Deep-sea',
#  'Dendraster excentricus',
#  'Dendrophyllia cornigera',
#  'Dendropoma petraeum',
#  'Derbesia marina',
#  'Derbesia tenuissima',
#  'Desmarestia aculeata',
#  'Desmarestia anceps',
#  'Desmarestia menziesii',
#  'Desmophyllum dianthus',
#  'Desmophyllum sp.',
#  'Development',
#  'Diacria trispinosa',
#  'Dicentrarchus labrax',
#  'Dichocoenia stokesii',
#  'Dichotomaria marginata',
#  'Dictyopteris polypodioides',
#  'Dictyota bartayresiana',
#  'Dictyota dichotoma',
#  'Dictyota sp.',
#  'Dilophus fasciola',
#  'Dinobryon balticum',
#  'Diogenes pugilator',
#  'Diopatra neapolitana',
#  'Diplodus sargus',
#  'Diploria labyrinthiformis',
#  'Dischistodus perspicillatus',
#  'Discosphaerina fagi',
#  'Ditylum brightwellii',
#  'Dolichospermum sp.',
#  'Doryteuthis pealeii',
#  'Dosidicus gigas',
#  'Dudresnaya verticillata',
#  'Dumontia incrassata',
#  'Dunaliella salina',
#  'Dunaliella tertiolecta',
#  'Duncanopsammia axifuga',
#  'Dynamene bifida',
#  'Dynamene torelliae',
#  'Echinaster sepositus',
#  'Echinocardium cordatum',
#  'Echinodermata',
#  'Echinometra lucunter',
#  'Echinometra mathaei',
#  'Echinometra sp.',
#  'Echinometra viridis',
#  'Echinopora lamellosa',
#  'Ecklonia radiata',
#  'Elachista neglecta',
#  'Electra pilosa',
#  'Ellisolandia elongata',
#  'Elminius modestus',
#  'Elphidium advenum',
#  'Elphidium albiumbilicatum',
#  'Elphidium crispum',
#  'Elphidium excavatum',
#  'Elphidium excavatum clavatum',
#  'Elphidium excavatum excavatum',
#  'Elphidium gerthi',
#  'Elphidium incertum',
#  'Elphidium macellum',
#  'Elphidium margaritaceum',
#  'Elphidium sp.',
#  'Elphidium williamsoni',
#  'Embiotoca jacksoni',
#  'Emiliania huxleyi',
#  'Ensis siliqua',
#  'Entire community',
#  'Epinephelus bruneus',
#  'Epistomella bradyana',
#  'Eponides sp.',
#  'Ervilia castanea',
#  'Estuary',
#  'Eucampia zoodiacus',
#  'Eucidaris tribuloides',
#  'Eunicea flexuosa',
#  'Eunicea fusca',
#  'Eunicella singularis',
#  'Euphausia krohni',
#  'Euphausia superba',
#  'Eurypon major',
#  'Eurytemora affinis',
#  'Euterpina acutifrons',
#  'Evechinus chloroticus',
#  'Falkenbergia sp.',
#  'Favia fragum',
#  'Favites abdita',
#  'Favites halicora',
#  'Favites pentagona',
#  'Field experiment',
#  'Field observation',
#  'Flabellia petiolata',
#  'Flexopecten glaber',
#  'Foraminifera',
#  'Forsterygion lapillum',
#  'Fragilariopsis curta',
#  'Fragilariopsis cylindrus',
#  'Fragilariopsis kerguelensis',
#  'Fucus vesiculosus',
#  'Fundulus heteroclitus',
#  'Furcellaria lumbricalis',
#  'Gadus morhua',
#  'Galaxaura rugosa',
#  'Galaxea fascicularis',
#  'Galeolaria caespitosa',
#  'Gammarus locusta',
#  'Gasterosteus aculeatus',
#  'Geminigera cryophila',
#  'Gene expression (incl. proteomics)',
#  'Gephyrocapsa oceanica',
#  'Gibberulus gibberulus gibbosus',
#  'Gillichthys mirabilis',
#  'Globigerina bulloides',
#  'Globigerinella siphonifera',
#  'Globigerinoides ruber',
#  'Globigerinoides sacculifer',
#  'Gloiocladia furcata',
#  'Gloiocladia microspora',
#  'Glycera alba',
#  'Gnathia aureamaculosa',
#  'Gobiusculus flavescens',
#  'Gondogeneia antarctica',
#  'Goniopora sp.',
#  'Gonyaulax sp.',
#  'Gonyaulax spinifera',
#  'Gracillaria salicornia',
#  'Griffithsia genovefae',
#  'Griffithsia opuntioides',
#  'Griffithsia sp.',
#  'Growth/Morphology',
#  'Guehomyces pullulans',
#  'Guinardia flaccida',
#  'Guinardia sp.',
#  'Gymnodinium arcticum',
#  'Gymnodinium sp.',
#  'Gyrodinium fusiforme',
#  'Haematocelis rubens',
#  'Haliclona mediterranea',
#  'Halimeda cuneata',
#  'Halimeda cylindracea',
#  'Halimeda digitata',
#  'Halimeda incrassata',
#  'Halimeda macroloba',
#  'Halimeda minima',
#  'Halimeda opuntia',
#  'Halimeda taenicola',
#  'Halimeda tuna',
#  'Haliotis discus hannai',
#  'Haliotis diversicolor',
#  'Haliotis fulgens',
#  'Haliotis kamtschatkana',
#  'Haliotis rufescens',
#  'Haliotis tuberculata',
#  'Halodule uninervis',
#  'Halodule wrightii',
#  'Halopteris filicina',
#  'Halopteris scoparia',
#  'Halymenia elongata',
#  'Haminoea hydatis',
#  'Hanzawaia nitidula',
#  'Haploblepharus edwardsii',
#  'Haptophyta',
#  'Haraldia lenormandii',
#  'Haynesina depressula',
#  'Haynesina germanica',
#  'Hediste diversicolor',
#  'Heliocidaris crassispi',
#  'Heliocidaris erythrogramma',
#  'Hemicentrotus pulcherrimus',
#  'Hemigrapsus sanguineus',
#  'Hemimycale columella',
#  'Heminuera frondosa',
#  'Hemiscyllium ocellatum',
#  'Henricia oculata',
#  'Heterocapsa sp.',
#  'Heterodontus portusjacksoni',
#  'Heterosigma akashiwo',
#  'Heterostegina antillarum',
#  'Heterostegina depressa',
#  'Heterotrophic prokaryotes',
#  'Heterozostera tasmanica',
#  'Hexadella topsenti',
#  'Hexaplex trunculus',
#  'Hildenbrandia sp.',
#  'Hincksia mitchelliae',
#  'Hippoglossus hippoglossus',
#  'Holothuria forskali',
#  'Holothuria parva',
#  'Holothuria scabra',
#  'Holothuria tubulosa',
#  'Homarus americanus',
#  'Homarus gammarus',
#  'Hyas araneus',
#  'Hydroides crucigera',
#  'Hydroides elegans',
#  'Hydrolithon boreale',
#  'Hydrolithon onkodes',
#  'Hydrolithon reinboldii',
#  'Hydrolithon samoense',
#  'Hydrolithon sp.',
#  'Hyella sp.',
#  'Hypnea pannosa',
#  'Hypomesus pretiosus',
#  'Idiosepius pygmaeus',
#  'Idotea balthica',
#  'Idotea emarginata',
#  'Idotea resecata',
#  'Imantonia sp.',
#  'Immunology/Self-protection',
#  'Indian Ocean',
#  'Inorganic toxins',
#  'Ircinia oros',
#  'Ircinia variabilis',
#  'Irvinea boergesenii',
#  'Isochrysis galbana',
#  'Isognomon alatus',
#  'Isopora cuneata',
#  'Jania rubens',
#  'Jassa herdmani',
#  'Jasus lalandii',
#  'Kallymenia feldmannii',
#  'Kallymenia patens',
#  'Kallymenia requienii',
#  'Kallymenia sp.',
#  'Karenia mikimotoi',
#  'Karenia selliformis',
#  'Karlodinium veneficum',
#  'Katharina tunicata',
#  'Katodinium glaucum',
#  'Kondoa malvinella',
#  'Laboratory experiment',
#  'Laboratory strains',
#  'Labroides dimidiatus',
#  'Lacuna vincta',
#  'Laevipeneroplis bradyi',
#  'Lagena sp.',
#  'Laminaria hyperborea',
#  'Laminaria rodriguezii',
#  'Laminaria solidungula',
#  'Larimichthys crocea',
#  'Laternula elliptica',
#  'Lates calcarifer',
#  'Laurencia sp.',
#  'Leathesia mucosa',
#  'Lekanesphaera monodi',
#  'Leptastrea pruinosa',
#  'Leptastrea purpurea',
#  'Leptochiton asellus',
#  'Leptofauchea coralligena',
#  'Leptopsammia pruvoti',
#  'Leptuca thayeri',
#  'Leucetta chagosensis',
#  'Leucoraja erinacea',
#  'Leucosporidium scottii',
#  'Leuresthes tenuis',
#  'Light',
#  'Limacina helicina',
#  'Limacina helicina antarctica',
#  'Limacina retroversa',
#  'Limecola balthica',
#  'Lingulodinium polyedrum',
#  'Liocarcinus arcuatus',
#  'Liothyrella uva',
#  'Lithodes aequispinus',
#  'Lithophyllum atlanticum',
#  'Lithophyllum cabiochae',
#  'Lithophyllum congestum',
#  'Lithophyllum flavescens',
#  'Lithophyllum incrustans',
#  'Lithophyllum kotschyanum',
#  'Lithophyllum prototypum',
#  'Lithophyllum sp.',
#  'Lithophyllum stictaeforme',
#  'Lithothamnion corallioides',
#  'Lithothamnion crispatum',
#  'Lithothamnion glaciale',
#  'Lithothamnion sp.',
#  'Lithothamnion valens',
#  'Litiorina littorea',
#  'Litopenaeus vannamei',
#  'Littorina fabalis',
#  'Littorina littorea',
#  'Littorina obtusata',
#  'Littorina saxatilis',
#  'Lobatula lobatula',
#  'Lobophora papenfussii',
#  'Lobophora variegata',
#  'Lobophytum pauciflorum',
#  'Lohmaniella oviformis',
#  'Loligo vulgaris',
#  'Lomentaria australis',
#  'Lomentaria chylocladiella',
#  'Lomentaria ercegovicii',
#  'Lomentaria subdichotoma',
#  'Lophelia pertusa',
#  'Loripes lacteus',
#  'Loxechinus albus',
#  'Loxostomum pseudoberyrichi',
#  'Luidia clathrata',
#  'Lutraria lutraria',
#  'Lysidice collaris',
#  'Lysidice ninetta',
#  'Lytechinus pictus',
#  'Lytechinus variegatus',
#  'Macoma balthica',
#  'Macro-nutrients',
#  'Macroalgae',
#  'Macrocystis pyrifera',
#  'Madracis mirabilis',
#  'Madrepora oculata',
#  'Magallana angulata',
#  'Magallana gigas',
#  'Magallana hongkongensis',
#  'Magellania venosa',
#  'Magelona johnstoni',
#  'Magelona mirabilis',
#  'Maguimithrax spinosissimus',
#  'Malacobelemnon daytoni',
#  'Margarella antarctica',
#  'Marginopora rossi',
#  'Marginopora vertebralis',
#  'Massilina gualtieriana',
#  'Mastigocoleus testarum',
#  'Mediterranean Sea',
#  'Melita palmata',
#  'Melosira arctica',
#  'Melyvonnea erubescens',
#  'Menidia beryllina',
#  'Menidia menidia',
#  'Menippe mercenaria',
#  'Mercenaria mercenaria',
#  'Meredithia microphylla',
#  'Meretrix meretrix',
#  'Merulina ampliata',
#  'Mesalia mesal',
#  'Mesocentrotus franciscanus',
#  'Mesocosm or benthocosm',
#  'Mesodinium rubrum',
#  'Mesophyllum alternans',
#  'Mesophyllum expansum',
#  'Metacarcinus magister',
#  'Metapenaeus monoceros',
#  'Metridium senile',
#  'Micro-nutrients',
#  'Microciona cf toxitenuis',
#  'Microglena sp.',
#  'Micromonas pusilla',
#  'Miliammina fusca',
#  'Miliola sp.',
#  'Miliolinella sp.',
#  'Miliolinella subrotunda',
#  'Mimachlamys asperrima',
#  'Mimosella gracilis',
#  'Mimosella verticillata',
#  'Mollusca',
#  'Montastraea cavernosa',
#  'Montipora aequituberculata',
#  'Montipora capitata',
#  'Montipora digitata',
#  'Montipora flabellata',
#  'Montipora foliosa',
#  'Montipora grisea',
#  'Montipora monasteriata',
#  'Montipora patula',
#  'Montipora sp.',
#  'Mopalia muscosa',
#  'Mortality/Survival',
#  'Musculista senhousia',
#  'Mya arenaria',
#  'Mycale grandis',
#  'Myriapora truncata',
#  'Myriogramme tristromatica',
#  'Myriotrichia adriatica',
#  'Mytella guyanensis',
#  'Mytilus californianus',
#  'Mytilus chilensis',
#  'Mytilus coruscus',
#  'Mytilus edulis',
#  'Mytilus galloprovincialis',
#  'Mytilus spp.',
#  'Mytilus trossulus',
#  'Myzozoa',
#  'Nacella concinna',
#  'Naso elegans',
#  'Nassarius conoidalis',
#  'Nassarius corniculus',
#  'Nassarius cuvieri',
#  'Nassarius festivus',
#  'Nassarius incrassatus',
#  'Nassarius nitidus',
#  'Nassarius pfeifferi',
#  'Nassarius pygmaeus',
#  'Nassarius reticulatus',
#  'Navicula granii',
#  'Navicula sp.',
#  'Navicula vanhoeffenii',
#  'Necora puber',
#  'Nekton',
#  'Nematostella vectensis',
#  'Neodenticula seminae',
#  'Neogloboquadrina incompta',
#  'Neogloboquadrina pachyderma',
#  'Neogoniolithon',
#  'Neogoniolithon brassica-florida',
#  'Neogoniolithon frutescens',
#  'Neogoniolithon mamillosum',
#  'Neogoniolithon sp.',
#  'Neogoniolithon spectabile',
#  'Neogonodactylus bredini',
#  'Neomonospora pedicellata var. tenuis',
#  'Neopetrosia compacta',
#  'Neopyropia yezoensis',
#  'Neosiphonia harveyi',
#  'Nephtys cirrosa',
#  'Nephtys hombergii',
#  'Neurocaulon foliosum',
#  'Nitophyllum flabellatum',
#  'Nitophyllum punctatum',
#  'Nitzschia closterium',
#  'Nitzschia closterium f.minutissima',
#  'Nitzschia lecointei',
#  'Nodularia spumigena',
#  'Nonionella basispinata',
#  'Nonionella sp.',
#  'North Atlantic',
#  'North Pacific',
#  'Not applicable',
#  'Notocidaris gaussensis',
#  'Notoclinops segmentatus',
#  'Notoclinops yaldwyni',
#  'Notothenia rossii',
#  'Nucella lapillus',
#  'Nucella ostrina',
#  'Nucula nucleus',
#  'Nucula sulcata',
#  'Nyctiphanes couchii',
#  'Ochrophyta',
#  'Ochrosphaera neapolitana',
#  'Oculina arbuscula',
#  'Oculina patagonica',
#  'Odontaster validus',
#  'Odontella weissflogii',
#  'Oikopleura dioica',
#  'Oithona davisae',
#  'Oithona similis',
#  'Oligochaeta sp.',
#  'Oncorhynchus gorbuscha',
#  'Oncorhynchus mykiss',
#  'Open ocean',
#  'Operculina ammonoides',
#  'Ophiocomina nigra',
#  'Ophiodon elongatus',
#  'Ophiothrix fragilis',
#  'Ophryotrocha japonica',
#  'Ophryotrocha labronica',
#  'Ophryotrocha robusta',
#  'Orbicella faveolata',
#  'Orbulina universa',
#  'Oreochromis mossambicus',
#  'Organic toxins',
#  'Oryzias melastigma',
#  'Oscillatoria sp.',
#  'Osilinus turbinatus',
#  'Osmundea pelagosae',
#  'Ostorhinchus cyanosoma',
#  'Ostorhinchus doederleini',
#  'Ostrea chilensis',
#  'Ostrea edulis',
#  'Ostrea lurida',
#  'Ostreobium sp.',
#  'Ostreococcus sp.',
#  'Ostreococcus tauri',
#  'Other',
#  'Other metabolic rates',
#  'Other studied parameter or process',
#  'Oxygen',
#  'Pachygrapsus crassipes',
#  'Pachygrapsus marmoratus',
#  'Pachyseris speciosa',
#  'Padina australis',
#  'Padina pavonica',
#  'Padina sp.',
#  'Pagurus bernhardus',
#  'Pagurus sp.',
#  'Pagurus tanneri',
#  'Palaemon elegans',
#  'Palaemon intermedius',
#  'Palaemon serenus',
#  'Palmaria palmata',
#  'Pandalus borealis',
#  'Panopea generosa',
#  'Panopeus herbstii',
#  'Panulirus interruptus',
#  'Paphia aurea',
#  'Paphia rhomboides',
#  'Paphia undulate',
#  'Parablennius laticlavius',
#  'Paracentrotus lividus',
#  'Paracyclopina nana',
#  'Paradexamine fissicauda',
#  'Parafavella sp.',
#  'Paralichthys dentatus',
#  'Paralichthys olivaceus',
#  'Paralithodes camtschaticus',
#  'Paralithodes platypus',
#  'Parazoanthus axinellae',
#  'Parorchis sp.',
#  'Parvicardium exiguum',
#  'Parvocalanus crassirostris',
#  'Patella caerulea',
#  'Patella rustica',
#  'Patella vulgata',
#  'Patinopecten yessoensis',
#  'Pavona cactus',
#  'Pecten maximus',
#  'Pelagos',
#  'Penaeus plebejus',
#  'Peneroplis pertusus',
#  'Peneroplis planatus',
#  'Peneroplis sp.',
#  'Pentapora fascialis',
#  'Peringia ulvae',
#  'Perna canaliculus',
#  'Perna perna',
#  'Perumytilus purpuratus',
#  'Petalonia sp.',
#  'Petrolisthes cinctipes',
#  'Petrosia ficiformis',
#  'Peyssonnelia crispata',
#  'Peyssonnelia dubyi',
#  'Peyssonnelia harveyana',
#  'Peyssonnelia inamoena',
#  'Peyssonnelia rosa-marina',
#  'Peyssonnelia sp.',
#  'Peyssonnelia squamaria',
#  'Phaedactylum tricornutum',
#  'Phaeocystis antarctica',
#  'Phaeocystis globosa',
#  'Phaeocystis pouchetii',
#  'Phaeodactylum tricornutum',
#  'Pherusella tubulosa',
#  'Philophthalmus sp.',
#  'Pholas dactylus',
#  'Phorbas ficticius',
#  'Phorbas fictitius',
#  'Phorbas tenacior',
#  'Phorcus sauciatus',
#  'Phyllacanthus imperialis',
#  'Phyllaplysia taylori',
#  'Phyllariopsis brevipes',
#  'Phyllophora crispa',
#  'Phymatolithon calcareum',
#  'Phymatolithon lusitanicum',
#  'Phytoplankton',
#  'Pileolina patelliformis',
#  'Pinna nobilis',
#  'Placopecten magellanicus',
#  'Planorbulina acervalis',
#  'Plantae',
#  'Platichthys flesus',
#  'Platygyra contorta',
#  'Platygyra daedalea',
#  'Platyhelminthes',
#  'Platynereis dumerilii',
#  'Plectonema terebrans',
#  'Plectropomus leopardus',
#  'Plesiastrea versipora',
#  'Pleurochrysis carterae',
#  'Pleurochrysis placolithoides',
#  'Plocamium angustum',
#  'Plocamium cartilagineum',
#  'Pneophyllum sp.',
#  'Pocillopora acuta',
#  'Pocillopora damicornis',
#  'Pocillopora eydouxi',
#  'Pocillopora meandrina',
#  'Pocillopora sp.',
#  'Pocillopora verrucosa',
#  'Polar',
#  'Polyophthalmus pictus',
#  'Polysiphonia elongella',
#  'Polysiphonia flocculosa',
#  'Polysiphonia fucoides',
#  'Polysiphonia subulifera',
#  'Pomacentrus amboinensis',
#  'Pomacentrus chrysurus',
#  'Pomacentrus moluccensis',
#  'Pomacentrus nagasakiensis',
#  'Pomacentrus wardi',
#  'Pomatoschistus pictus',
#  'Porella cervicornis',
#  'Porifera',
#  'Porifera unidentified',
#  'Porites annae',
#  'Porites astreoides',
#  'Porites compressa',
#  'Porites cylindrica',
#  'Porites divaricata',
#  'Porites evermanni',
#  'Porites furcata',
#  'Porites heronensis',
#  'Porites irregularis',
#  'Porites lobata',
#  'Porites lutea',
#  'Porites murrayensis',
#  'Porites panamensis',
#  'Porites porites',
#  'Porites rus',
#  'Porites sp.',
#  'Porolithon onkodes',
#  'Porphyra purpurea',
#  'Posidonia oceanica',
#  'Potamogeton perfoliatus',
#  'Praunus flexuosus',
#  'Primary production/Photosynthesis',
#  'Proboscia alata',
#  'Proboscia truncata',
#  'Prochlorococcus sp.',
#  'Prorocentrum micans',
#  'Prorocentrum minimum',
#  'Prorocentrum sp.',
#  'Proteobacteria',
#  'Protoceratium reticulatum',
#  'Psammechinus miliaris',
#  'Psammocora profundacella',
#  ...]

# %%
# Find number of datasets for each keyword for the 2 periods

dfreq = pd.DataFrame()
year = 2015

for k in allKeywordsDB:
    s_total = df[df['keyword'].apply(lambda x: bool(set(x) & set([k]) if x != None else []))]
    s_period1 = s_total[s_total['citation_date'].between('1950-01-01', str(year-1)+'-12-31')]
    s_period2 = s_total[s_total['citation_date'].between(str(year)+'-01-01', '2030-12-31')]
    dfreq = dfreq._append({ 'keyword': k, 
                    'before ' + str(year): len(s_period1), 
                    'after ' + str(year):  len(s_period2)}, 
                    ignore_index=True)

# %%
# Specify int type

dfreq = dfreq.astype({ 'before ' + str(year): int, 
            'after ' + str(year):  int
          })

# %%
# Save to CSV file

dfreq.to_csv('OA-ICC_keywords_before_after_2015.csv', index=False)

# %%
dfreq
# Out:
#                 keyword  before 2015  after 2015
# 0     Abatus cavernosus            0           0
# 1             Abra alba            1           0
# 2           Abra nitida            1           0
# 3       Abra prismatica            1           0
# 4           Abra tenuis            1           0
# ...                 ...          ...         ...
# 1237   Zostera japonica            0           0
# 1238     Zostera marina            0           1
# 1239   Zostera muelleri            1           0
# 1240     Zostera noltii            0           1
# 1241    massive Porites            0           0
#
# [1242 rows x 3 columns]
