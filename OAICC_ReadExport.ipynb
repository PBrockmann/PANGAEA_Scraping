# %% [markdown]
# ### Read exported bibliodatabase files

# %%
import pandas as pd
import csv

# %%
tagDate = '20211203'

# %%
dfArray = []

# %%
file = 'OAICCincomplete_' + tagDate + '.utf8'

df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Not included'
df['Reason for non inclusion'] = '< 2 carbonate chemistry parameters'

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 1  Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 2  Aires, T., Serebryakova, A., Viard, F., Serrão...
# 3  Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
# 4  Al-Janabi, B., Kruse, I., Graiff, A., Winde, V...
#
#                                 DOI      Country  Year Included/Not included  \
# 0             doi:10.1111/jfd.12417   EU-Austria  2016          Not included
# 1            doi:10.3390/min4010145          USA  2014          Not included
# 2            doi:10.7717/peerj.4377  EU-Portugal  2018          Not included
# 3    doi:10.17576/mjas-2019-2306-10     Malaysia  2019          Not included
# 4  doi:10.1371/journal.pone.0152948   EU-Germany  2016          Not included
#
#              Reason for non inclusion
# 0  < 2 carbonate chemistry parameters
# 1  < 2 carbonate chemistry parameters
# 2  < 2 carbonate chemistry parameters
# 3  < 2 carbonate chemistry parameters
# 4  < 2 carbonate chemistry parameters

# %%
file = 'OAICCnoanswer_' + tagDate + '.utf8'

df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Not included'
df['Reason for non inclusion'] = 'No answer from authors'

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Achlatis, M., van der Zande, R. M., Schönberg,...
# 1  Agnalt, A.-L., Grefsrud, E. S., Farestveit, E....
# 2  Aguayo, P., Campos, V. L., Henríquez, C., Oliv...
# 3  Al-Janabi, B., Kruse, I., Graiff, A., Karsten,...
# 4  Albert, G., Hepburn, C. D., Pajusalu, L., Paal...
#
#                                  DOI     Country  Year Included/Not included  \
# 0     doi:10.1038/s41598-017-10947-1   Australia  2017          Not included
# 1        doi:10.5194/bg-10-7883-2013   EU-Norway  2013          Not included
# 2  doi:10.3390/microorganisms8121924       Chile  2020          Not included
# 3      doi:10.1007/s00227-015-2804-8  EU-Germany  2016          Not included
# 4     doi:10.1007/s10811-019-01953-z  EU-Estonia  2019          Not included
#
#   Reason for non inclusion
# 0   No answer from authors
# 1   No answer from authors
# 2   No answer from authors
# 3   No answer from authors
# 4   No answer from authors

# %%
file = 'OAICCdatalost_' + tagDate + '.utf8'

df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Not included'
df['Reason for non inclusion'] = 'Data lost'

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Broecker, W. S., Langdon, C., & Takahashi, T.,...
# 1  Burkhardt, S., Amoroso, G., Riebesell, U., & S...
# 2  Burkhardt, S., & Riebesell, U., 1997. CO2 avai...
# 3  Burkhardt, S., Riebesell, U., & Zondervan, I.,...
# 4  Burkhardt, S., Zondervan, I., & Riebesell, U.,...
#
#                                  DOI     Country  Year Included/Not included  \
# 0           doi:10.1029/2000GB001350         USA  2001          Not included
# 1      doi:10.4319/lo.2001.46.6.1378  EU-Germany  2001          Not included
# 2             doi:10.3354/meps155067  EU-Germany  1997          Not included
# 3  doi:10.1016/S0016-7037(99)00217-3  EU-Germany  1999          Not included
# 4      doi:10.4319/lo.1999.44.3.0683  EU-Germany  1999          Not included
#
#   Reason for non inclusion
# 0                Data lost
# 1                Data lost
# 2                Data lost
# 3                Data lost
# 4                Data lost

# %%
file = 'OAICCdb_' + tagDate + '.utf8'

df = pd.read_csv(file, sep=';', encoding='utf_8', names=['Reference', 'DOI', 'DOI_PANGAEA', 'Country', 'Year'])
df['Reference'] = df['Reference'].str.strip()
df['DOI'] = df['DOI'].str.strip()
df['DOI_PANGAEA'] = df['DOI_PANGAEA'].str.strip()
df['Country'] = df['Country'].str.strip()
df['Year'] = df['Year']
df['Included/Not included'] = 'Included'
df['Reason for non inclusion'] = ''

dfArray.append(df)

df.head()
# Out:
#                                            Reference  \
# 0  Ab Lah, R., Kelaher, B. P., Bucher, D., & Benk...
# 1  Aberle, N., Schulz, K. G., Stuhr, A., Malzahn,...
# 2  Agostini, S., Fujimura, H., Higuchi, T., Yuyam...
# 3  Aguilera, V. M., 2020. pH and other upwelling ...
# 4  Aguilera, V. M., Escribano, R., Vargas, C. A.,...
#
#                                    DOI             DOI_PANGAEA     Country  \
# 0  doi:10.1016/j.marenvres.2018.08.009  10.1594/PANGAEA.902088    Malaysia
# 1          doi:10.5194/bg-10-1471-2013  10.1594/PANGAEA.832403  EU-Germany
# 2       doi:10.1016/j.crvi.2013.07.003  10.1594/PANGAEA.835319       Japan
# 3       doi:10.1016/j.ecss.2020.106640  10.1594/PANGAEA.925454       Chile
# 4     doi:10.1371/journal.pone.0209823  10.1594/PANGAEA.925450       Chile
#
#    Year Included/Not included Reason for non inclusion
# 0  2018              Included
# 1  2013              Included
# 2  2013              Included
# 3  2020              Included
# 4  2019              Included

# %%
df = pd.concat(dfArray, sort=False)
print(len(df))

df[['Reference', 'DOI', 'DOI_PANGAEA', 'Included/Not included', 'Reason for non inclusion', 'Country', 'Year']]\
    .to_csv('OAICC_' + tagDate + '.csv', index=False, encoding='utf_8', quoting=csv.QUOTE_ALL)
# Out:
# 2823

# %%
df
# Out:
#                                               Reference  \
# 0     Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 1     Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 2     Aires, T., Serebryakova, A., Viard, F., Serrão...
# 3     Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
# 4     Al-Janabi, B., Kruse, I., Graiff, A., Winde, V...
# ...                                                 ...
# 1264  Zittier, Z. M. C., Hirse, T., & Pörtner, H.-O....
# 1265  Ziveri, P., Passaro, M., Incarbona, A., Milazz...
# 1266  Zlatkin, R. L., & Heuer, R. M., 2019. Ocean ac...
# 1267  Zondervan, I., Rost, B., & Riebesell, U., 2002...
# 1268  Zondervan, I., Zeebe, R. E., Rost, B., & Riebe...
#
#                                     DOI      Country  Year  \
# 0                 doi:10.1111/jfd.12417   EU-Austria  2016
# 1                doi:10.3390/min4010145          USA  2014
# 2                doi:10.7717/peerj.4377  EU-Portugal  2018
# 3        doi:10.17576/mjas-2019-2306-10     Malaysia  2019
# 4      doi:10.1371/journal.pone.0152948   EU-Germany  2016
# ...                                 ...          ...   ...
# 1264      doi:10.1007/s00227-012-2073-8   EU-Germany  2013
# 1265          doi:10.1086/BBLv226n3p282     EU-Spain  2014
# 1266            doi:10.1098/rsos.191041          USA  2019
# 1267  doi:10.1016/S0022-0981(02)00037-0   EU-Germany  2002
# 1268           doi:10.1029/2000GB001321   EU-Germany  2001
#
#      Included/Not included            Reason for non inclusion  \
# 0             Not included  < 2 carbonate chemistry parameters
# 1             Not included  < 2 carbonate chemistry parameters
# 2             Not included  < 2 carbonate chemistry parameters
# 3             Not included  < 2 carbonate chemistry parameters
# 4             Not included  < 2 carbonate chemistry parameters
# ...                    ...                                 ...
# 1264              Included
# 1265              Included
# 1266              Included
# 1267              Included
# 1268              Included
#
#                  DOI_PANGAEA
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 1264  10.1594/PANGAEA.821402
# 1265  10.1594/PANGAEA.838830
# 1266  10.1594/PANGAEA.912287
# 1267  10.1594/PANGAEA.726883
# 1268  10.1594/PANGAEA.726883
#
# [2823 rows x 7 columns]
