# %% [markdown]
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)
#
#  * 2023/09/19 - initial revision
#
# <img align="left" width="50%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" >

# %% [markdown]
# ### Harvesting metadata

# %% [markdown]
# Change havesting technic from Elastic request to the use of the Open Archives Initiative Protocol for Metadata Harvesting (OAI-PMH).
#
# https://dataportals.pangaea.de/oa-icc/index2.php?
#
# http://ws.pangaea.de/es/dataportal-oa-icc/pansimple/_search?q=_id:PANGAEA.903033&pretty=true
#
# http://ws.pangaea.de/es/dataportal-oa-icc/pansimple/_search?size=10&_source_include=*Longitude,*Latitude,citation_title,citation_date,description,keyword,format,metadatalink,citation_authors,datalink
#
# to
#
# https://www.openarchives.org/pmh/
#
# http://ws.pangaea.de/oai/provider?verb=ListMetadataFormats
#
# http://ws.pangaea.de/oai/provider?verb=GetRecord&metadataPrefix=pan_md&identifier=oai:pangaea.de:doi:10.1594/PANGAEA.903033
#
# Choose pan_md

# %%
# https://github.com/bloomonkey/oai-harvest
# oai-harvest -p pan_md -d oaiharvest --set project4173 http://ws.pangaea.de/oai/provider

# %% [markdown]
# ### Exemple with one pan_md XML file

# %%
#import requests
from bs4 import BeautifulSoup

#url = "http://ws.pangaea.de/oai/provider?verb=GetRecord&metadataPrefix=pan_md&identifier=oai:pangaea.de:doi:10.1594/PANGAEA.959648"
#url = "http://ws.pangaea.de/oai/provider?verb=GetRecord&metadataPrefix=dif&identifier=oai:pangaea.de:doi:10.1594/PANGAEA.959648"
#page = requests.get(url)
#soup = BeautifulSoup(page.content, "xml")

# oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.959648.pan_md.xml

#XMLFileToBeOpened = open("oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.726955.pan_md.xml", "r")
#XMLFileToBeOpened = open("oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.833328.pan_md.xml", "r")
XMLFileToBeOpened = open("oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.819639.pan_md.xml", "r")

pageContent = XMLFileToBeOpened.read()
soup = BeautifulSoup(pageContent, "xml")
XMLFileToBeOpened.close()

# %%
DOI = soup.find('md:citation').find('md:URI', recursive=False).text
DOI = DOI.replace('doi.org', 'doi.pangaea.de')     # need for creating a dataLink 
DOI
# Out:
# 'https://doi.pangaea.de/10.1594/PANGAEA.819639'

# %%
title = soup.find('md:citation').find('md:title').text
title
# Out:
# 'Seawater carbonate chemistry in Hog reef and calcification rate in the Bermuda reef community, 2010'

# %%
yearCitation = soup.find('md:citation').find('md:year').text
yearCitation
# Out:
# '2010'

# %%
try:
    yearSupplementTo = soup.find('md:reference', {'relationType': 'Supplement to'}).find('md:year').text
    yearSupplementTo
except:
    None

# %%
contents = soup.find('md:citation').findAll('md:author', recursive=False)
lastNames = [content.find('md:lastName').text for content in contents]

try:
    firstNames = [content.find('md:firstName').text for content in contents]
    authors = list(map(lambda x,y: x + ', ' + y, lastNames, firstNames))
except:
    authors = lastNames

authors
# Out:
# ['Bates, Nicolas R', 'Amat, A', 'Andersson, Andreas J']

# %%
contents = soup.find('md:keywords').findAll('md:keyword', {'type':'fromDatabase'})
keywords = [content.contents[0] for content in contents]
keywords
# Out:
# ['Benthos',
#  'Calcification/Dissolution',
#  'Coast and continental shelf',
#  'Entire community',
#  'Field observation',
#  'North Atlantic',
#  'Rocky-shore community',
#  'Temperate']

# %%
abstract = soup.find('md:abstract').text
abstract
# Out:
# 'Despite the potential impact of ocean acidification on ecosystems such as coral reefs, surprisingly, there is very limited field data on the relationships between calcification and seawater carbonate chemistry. In this study, contemporaneous in situ datasets of seawater carbonate chemistry and calcification rates from the high-latitude coral reef of Bermuda over annual timescales provide a framework for investigating the present and future potential impact of rising carbon dioxide (CO2) levels and ocean acidification on coral reef ecosystems in their natural environment. A strong correlation was found between the in situ rates of calcification for the major framework building coral species Diploria labyrinthiformis and the seasonal variability of [CO32-] and aragonite saturation state omega aragonite, rather than other environmental factors such as light and temperature. These field observations provide sufficient data to hypothesize that there is a seasonal "Carbonate Chemistry Coral Reef Ecosystem Feedback" (CREF hypothesis) between the primary components of the reef ecosystem (i.e., scleractinian hard corals and macroalgae) and seawater carbonate chemistry. In early summer, strong net autotrophy from benthic components of the reef system enhance [CO32-] and omega aragonite conditions, and rates of coral calcification due to the photosynthetic uptake of CO2. In late summer, rates of coral calcification are suppressed by release of CO2 from reef metabolism during a period of strong net heterotrophy. It is likely that this seasonal CREF mechanism is present in other tropical reefs although attenuated compared to high-latitude reefs such as Bermuda. Due to lower annual mean surface seawater [CO32-] and omega aragonite in Bermuda compared to tropical regions, we anticipate that Bermuda corals will experience seasonal periods of zero net calcification within the next decade at [CO32-] and omega aragonite thresholds of ~184 micro moles kg-1 and 2.65. However, net autotrophy of the reef during winter and spring (as part of the CREF hypothesis) may delay the onset of zero NEC or decalcification going forward by enhancing [CO32-] and omega aragonite. The Bermuda coral reef is one of the first responders to the negative impacts of ocean acidification, and we estimate that calcification rates for D. labyrinthiformis have declined by >50% compared to pre-industrial times.'

# %%
contents = soup.find('technicalInfo').find('md:entry', {'key':'mimeType'})
mimeTypeData = contents['value']

mimeTypeData
# 2 values detected: 'application/zip' and 'text/tab-separated-values'
# Out:
# 'application/zip'

# %% [markdown]
# ### Loop over all harvested files '*.pan_md.xml'

# %%
from pathlib import Path
import csv

# %%
with open('out.csv', 'w', newline='') as csvFile:
    csvWriter = csv.writer(csvFile, delimiter=';')

    paths = Path("oaiharvest").glob('*.pan_md.xml')
    for n,path in enumerate(paths):
        
        if (n%50 == 0):
            print(n,path)
    
        #----------------
        XMLFileToBeOpened = open(path, "r")
        pageContent = XMLFileToBeOpened.read()
        soup = BeautifulSoup(pageContent, "xml")
        XMLFileToBeOpened.close()
    
        #----------------
        DOI = soup.find('md:citation').find('md:URI', recursive=False).text
        DOI = DOI.replace('doi.org', 'doi.pangaea.de')

        #----------------
        title = soup.find('md:citation').find('md:title').text
    
        #----------------
        yearCitation = soup.find('md:citation').find('md:year').text
    
        #----------------
        try:
            yearSupplementTo = soup.find('md:reference', {'relationType': 'Supplement to'}).find('md:year').text
        except:
            yearSupplementTo = None
    
        #----------------
        contents = soup.find('md:keywords').findAll('md:keyword', {'type':'fromDatabase'})
        keywords = [content.contents[0] for content in contents]
        
        #----------------
        try:
            abstract = soup.find('md:abstract').text
        except:
            abstract = None
            
        #----------------
        contents = soup.find('md:citation').findAll('md:author', recursive=False)
        lastNames = [content.find('md:lastName').text for content in contents]
        try:
            firstNames = [content.find('md:firstName').text for content in contents]
            authors = list(map(lambda x,y: x + ', ' + y, lastNames, firstNames))
        except:
            authors = lastNames    # when first names not present 
        
        #----------------
        contents = soup.find('technicalInfo').find('md:entry', {'key':'mimeType'})
        mimeTypeData = contents['value']
        
        if (mimeTypeData == 'text/tab-separated-values') :
            dataLink = DOI + "?format=textfile"
        elif (mimeTypeData == 'application/zip') :
            dataLink = DOI + "?format=zip"
        else:
            print("ERROR: unknow mimeType for dataLink: ", mimeTypeData)
            break
    
        #----------------
        csvWriter.writerow([DOI, title, yearCitation, yearSupplementTo, keywords, abstract, authors, dataLink])

csvFile.close()
# Out:
# 0 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.835969.pan_md.xml
# 50 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.926447.pan_md.xml
# 100 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.839180.pan_md.xml
# 150 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.958450.pan_md.xml
# 200 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.874781.pan_md.xml
# 250 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.908297.pan_md.xml
# 300 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.867479.pan_md.xml
# 350 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.952281.pan_md.xml
# 400 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.859285.pan_md.xml
# 450 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.727746.pan_md.xml
# 500 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.941907.pan_md.xml
# 550 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.875042.pan_md.xml
# 600 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.848775.pan_md.xml
# 650 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.924889.pan_md.xml
# 700 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.922623.pan_md.xml
# 750 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.883315.pan_md.xml
# 800 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.953111.pan_md.xml
# 850 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.956150.pan_md.xml
# 900 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.899869.pan_md.xml
# 950 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.934128.pan_md.xml
# 1000 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.823460.pan_md.xml
# 1050 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.833014.pan_md.xml
# 1100 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.823078.pan_md.xml
# 1150 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.960341.pan_md.xml
# 1200 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.733947.pan_md.xml
# 1250 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.763289.pan_md.xml
# 1300 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.875086.pan_md.xml
# 1350 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.848673.pan_md.xml
# 1400 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.946411.pan_md.xml
# 1450 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.944930.pan_md.xml
# 1500 oaiharvest/oai:pangaea.de:doi:10.1594%2FPANGAEA.835643.pan_md.xml

# %% [markdown]
# ### Data processing (dates consolidation)

# %%
import pandas as pd

# %%
df = pd.read_csv('out.csv', sep=';', 
                 names=['DOI', 'title', 'yearCitation', 'yearSupplementTo', 'keywords', 'abstract', 'authors', 'dataLink'], 
                 header=None, na_values=[''])
df['yearCitation'] = pd.to_datetime(df['yearCitation'], format='%Y')
df['yearSupplementTo'] = pd.to_datetime(df['yearSupplementTo'], format='%Y')
df['keywords'] = df['keywords'].apply(lambda x: eval(x))
df['authors'] = df['authors'].apply(lambda x: eval(x))
df
# Out:
#                                                 DOI  \
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912
# ...                                             ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643
#
#                                                   title yearCitation  \
# 0     Acid-base physiology response to ocean acidifi...   2014-01-01
# 1     Seawater carbonate chemistry, nutrients, and C...   2012-01-01
# 2     Control of ambient pH on growth and stable iso...   2015-01-01
# 3     Seawater carbonate chemistry and growth, carbo...   2013-01-01
# 4     Strong shift from HCO3- to CO2 uptake in Emili...   2014-01-01
# ...                                                 ...          ...
# 1496  Sea urchins in a high CO2 world: partitioned e...   2016-01-01
# 1497  Seawater carbonate chemistry and immune respon...   2017-01-01
# 1498  Calcareous green alga Halimeda tolerates ocean...   2015-01-01
# 1499  Seawater carbonate chemistry and physiological...   2011-01-01
# 1500  Effects of hypercapnia on aspects of feeding, ...   2014-01-01
#
#      yearSupplementTo                                           keywords  \
# 0                 NaT  [Acid-base regulation, Animalia, Benthic anima...
# 1                 NaT  [Biomass/Abundance/Elemental composition, Bott...
# 2                 NaT  [Biomass/Abundance/Elemental composition, Bott...
# 3                 NaT  [Antarctic, Bottles or small containers/Aquari...
# 4                 NaT  [Biomass/Abundance/Elemental composition, Bott...
# ...               ...                                                ...
# 1496              NaT  [Animalia, Behaviour, Benthic animals, Benthos...
# 1497              NaT  [Animalia, Benthic animals, Benthos, Coast and...
# 1498              NaT  [Benthos, Biomass/Abundance/Elemental composit...
# 1499       2011-01-01  [Animalia, Behaviour, Benthic animals, Benthos...
# 1500              NaT  [Animalia, Behaviour, Benthic animals, Benthos...
#
#                                                abstract  \
# 0     Sea cucumbers are dominant invertebrates in se...
# 1     The coccolithophore Calcidiscus leptoporus was...
# 2     The present work examines the relationship bet...
# 3     Despite the fact that ocean acidification is c...
# 4     Effects of ocean acidification on Emiliania hu...
# ...                                                 ...
# 1496  Body-size and temperature are the major factor...
# 1497  Ocean acidification (OA) is one of the main co...
# 1498  We investigated ecological, physiological, and...
# 1499  Effects of coastal ocean acidification, other ...
# 1500  Land-based aquaculture facilities experience o...
#
#                                                 authors  \
# 0     [Collard, Marie, Eeckhaut, Igor, Dehairs, Fran...
# 1     [Langer, Gerald, Oetjen, Kerstin, Brenneis, Tina]
# 2                                    [Hermoso, Michael]
# 3     [Trimborn, Scarlett, Brenneis, Tina, Sweet, El...
# 4     [Kottmeier, Dorothee, Rokitta, Sebastian D, To...
# ...                                                 ...
# 1496  [Carey, Nicholas, Harianto, Januar, Byrne, Maria]
# 1497  [Castillo, Nicole, Saavedra, Luisa M, Vargas, ...
# 1498  [Vogel, Nikolas, Fabricius, Katharina Elisabet...
# 1499  [Fernández-Reiriz, Ma José, Range, P, Alvarez-...
# 1500  [Challener, Roberta C, Watts, Stephen A, McCli...
#
#                                                dataLink
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969?...
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475?...
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380?...
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406?...
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912?...
# ...                                                 ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079?...
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698?...
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875?...
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645?...
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643?...
#
# [1501 rows x 8 columns]

# %%
df['keywords'][0]
# Out:
# ['Acid-base regulation',
#  'Animalia',
#  'Benthic animals',
#  'Benthos',
#  'Coast and continental shelf',
#  'Containers and aquaria (20-1000 L or < 1 m**2)',
#  'Echinodermata',
#  'Holothuria parva',
#  'Holothuria scabra',
#  'Indian Ocean',
#  'Laboratory experiment',
#  'Other metabolic rates',
#  'Respiration',
#  'Single species',
#  'Tropical']

# %%
df['authors'][0]
# Out:
# ['Collard, Marie', 'Eeckhaut, Igor', 'Dehairs, Frank', 'Dubois, Philippe']

# %%
df[df['yearCitation'] < df['yearSupplementTo']]
# Out:
#                                                 DOI  \
# 149   https://doi.pangaea.de/10.1594/PANGAEA.924887
# 549   https://doi.pangaea.de/10.1594/PANGAEA.943567
# 910   https://doi.pangaea.de/10.1594/PANGAEA.917470
# 923   https://doi.pangaea.de/10.1594/PANGAEA.942405
# 975   https://doi.pangaea.de/10.1594/PANGAEA.923155
# 1041  https://doi.pangaea.de/10.1594/PANGAEA.950764
# 1266  https://doi.pangaea.de/10.1594/PANGAEA.929722
# 1309  https://doi.pangaea.de/10.1594/PANGAEA.930934
# 1337  https://doi.pangaea.de/10.1594/PANGAEA.955376
#
#                                                   title yearCitation  \
# 149   Seawater carbonate chemistry and growth,cellul...   2019-01-01
# 549   Seawater carbonate chemistry and carbonate che...   2021-01-01
# 910   Seawater carbonate chemistry and phytoplankton...   2019-01-01
# 923   Seawater carbonate chemistry and bacterial div...   2021-01-01
# 975   Seawater carbonate chemistry and population st...   2020-01-01
# 1041  Seawater carbonate chemistry and survival in C...   2012-01-01
# 1266  Seawater carbonate chemistry and acid-base phy...   2020-01-01
# 1309  Seawater carbonate chemistry and estuarine dis...   2020-01-01
# 1337  Seawater carbonate chemistry and the acute str...   2022-01-01
#
#      yearSupplementTo                                           keywords  \
# 149        2020-01-01  [Arctic, Biomass/Abundance/Elemental compositi...
# 549        2022-01-01  [Acid-base regulation, Bacteria, Baltic Sea, B...
# 910        2020-01-01  [CO2 vent, Coast and continental shelf, Commun...
# 923        2022-01-01  [Animalia, Benthic animals, Benthos, Bottles o...
# 975        2021-01-01  [Animalia, Benthic animals, Benthos, Biomass/A...
# 1041       2013-01-01  [Animalia, Arthropoda, Benthic animals, Bentho...
# 1266       2021-01-01  [Acid-base regulation, Animalia, Antarctic, Be...
# 1309       2021-01-01  [Benthos, Bottles or small containers/Aquaria ...
# 1337       2023-01-01  [Animalia, Behaviour, Chordata, Containers and...
#
#                                                abstract  \
# 149   Compared to the rest of the globe, the Arctic ...
# 549   Photosynthesis and respiration cause distinct ...
# 910   In situ effects of ocean acidification are inc...
# 923   The sponge-associated microbial community cont...
# 975   Sites with naturally high CO2 conditions provi...
# 1041  Ocean acidification (OA) may alter the behavio...
# 1266  Antarctic surface waters are expected to be th...
# 1309  Relative to their surface area, estuaries make...
# 1337  The absorption of anthropogenic carbon dioxide...
#
#                                                 authors  \
# 149   [White, Emily, Hoppe, Clara Jule Marie, Rost, ...
# 549   [Eichner, Meri, Wolf-Gladrow, Dieter A, Ploug,...
# 910   [Zitoun, Rebecca, Connell, Sean D, Cornwall, C...
# 923   [Posadas, Niño, Baquiran, Jake Ivan P, Nada, M...
# 975   [Martins, M, Carreiro-Silva, Marina, Martins, ...
# 1041  [Roberts, David A, Birchenough, Silvana N R, L...
# 1266  [Di Giglio, Sarah, Agüera, Antonio, Pernet, Ph...
# 1309  [Simone, Michelle, Schulz, Kai, Oakes, Joanne,...
# 1337  [Servili, Arianna, Lévêque, Etienne, Mouchel, ...
#
#                                                dataLink
# 149   https://doi.pangaea.de/10.1594/PANGAEA.924887?...
# 549   https://doi.pangaea.de/10.1594/PANGAEA.943567?...
# 910   https://doi.pangaea.de/10.1594/PANGAEA.917470?...
# 923   https://doi.pangaea.de/10.1594/PANGAEA.942405?...
# 975   https://doi.pangaea.de/10.1594/PANGAEA.923155?...
# 1041  https://doi.pangaea.de/10.1594/PANGAEA.950764?...
# 1266  https://doi.pangaea.de/10.1594/PANGAEA.929722?...
# 1309  https://doi.pangaea.de/10.1594/PANGAEA.930934?...
# 1337  https://doi.pangaea.de/10.1594/PANGAEA.955376?...

# %%
# Consider yearSupplementTo as correct is present otherwise fill by yearCitation
df['year'] = df['yearSupplementTo'].fillna(df['yearCitation'])
df['year'] = df['year'].dt.year
df
# Out:
#                                                 DOI  \
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912
# ...                                             ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643
#
#                                                   title yearCitation  \
# 0     Acid-base physiology response to ocean acidifi...   2014-01-01
# 1     Seawater carbonate chemistry, nutrients, and C...   2012-01-01
# 2     Control of ambient pH on growth and stable iso...   2015-01-01
# 3     Seawater carbonate chemistry and growth, carbo...   2013-01-01
# 4     Strong shift from HCO3- to CO2 uptake in Emili...   2014-01-01
# ...                                                 ...          ...
# 1496  Sea urchins in a high CO2 world: partitioned e...   2016-01-01
# 1497  Seawater carbonate chemistry and immune respon...   2017-01-01
# 1498  Calcareous green alga Halimeda tolerates ocean...   2015-01-01
# 1499  Seawater carbonate chemistry and physiological...   2011-01-01
# 1500  Effects of hypercapnia on aspects of feeding, ...   2014-01-01
#
#      yearSupplementTo                                           keywords  \
# 0                 NaT  [Acid-base regulation, Animalia, Benthic anima...
# 1                 NaT  [Biomass/Abundance/Elemental composition, Bott...
# 2                 NaT  [Biomass/Abundance/Elemental composition, Bott...
# 3                 NaT  [Antarctic, Bottles or small containers/Aquari...
# 4                 NaT  [Biomass/Abundance/Elemental composition, Bott...
# ...               ...                                                ...
# 1496              NaT  [Animalia, Behaviour, Benthic animals, Benthos...
# 1497              NaT  [Animalia, Benthic animals, Benthos, Coast and...
# 1498              NaT  [Benthos, Biomass/Abundance/Elemental composit...
# 1499       2011-01-01  [Animalia, Behaviour, Benthic animals, Benthos...
# 1500              NaT  [Animalia, Behaviour, Benthic animals, Benthos...
#
#                                                abstract  \
# 0     Sea cucumbers are dominant invertebrates in se...
# 1     The coccolithophore Calcidiscus leptoporus was...
# 2     The present work examines the relationship bet...
# 3     Despite the fact that ocean acidification is c...
# 4     Effects of ocean acidification on Emiliania hu...
# ...                                                 ...
# 1496  Body-size and temperature are the major factor...
# 1497  Ocean acidification (OA) is one of the main co...
# 1498  We investigated ecological, physiological, and...
# 1499  Effects of coastal ocean acidification, other ...
# 1500  Land-based aquaculture facilities experience o...
#
#                                                 authors  \
# 0     [Collard, Marie, Eeckhaut, Igor, Dehairs, Fran...
# 1     [Langer, Gerald, Oetjen, Kerstin, Brenneis, Tina]
# 2                                    [Hermoso, Michael]
# 3     [Trimborn, Scarlett, Brenneis, Tina, Sweet, El...
# 4     [Kottmeier, Dorothee, Rokitta, Sebastian D, To...
# ...                                                 ...
# 1496  [Carey, Nicholas, Harianto, Januar, Byrne, Maria]
# 1497  [Castillo, Nicole, Saavedra, Luisa M, Vargas, ...
# 1498  [Vogel, Nikolas, Fabricius, Katharina Elisabet...
# 1499  [Fernández-Reiriz, Ma José, Range, P, Alvarez-...
# 1500  [Challener, Roberta C, Watts, Stephen A, McCli...
#
#                                                dataLink  year
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969?...  2014
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475?...  2012
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380?...  2015
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406?...  2013
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912?...  2014
# ...                                                 ...   ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079?...  2016
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698?...  2017
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875?...  2015
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645?...  2011
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643?...  2014
#
# [1501 rows x 9 columns]

# %%
df.drop(columns=['yearCitation','yearSupplementTo'], inplace=True)
df
# Out:
#                                                 DOI  \
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912
# ...                                             ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643
#
#                                                   title  \
# 0     Acid-base physiology response to ocean acidifi...
# 1     Seawater carbonate chemistry, nutrients, and C...
# 2     Control of ambient pH on growth and stable iso...
# 3     Seawater carbonate chemistry and growth, carbo...
# 4     Strong shift from HCO3- to CO2 uptake in Emili...
# ...                                                 ...
# 1496  Sea urchins in a high CO2 world: partitioned e...
# 1497  Seawater carbonate chemistry and immune respon...
# 1498  Calcareous green alga Halimeda tolerates ocean...
# 1499  Seawater carbonate chemistry and physiological...
# 1500  Effects of hypercapnia on aspects of feeding, ...
#
#                                                keywords  \
# 0     [Acid-base regulation, Animalia, Benthic anima...
# 1     [Biomass/Abundance/Elemental composition, Bott...
# 2     [Biomass/Abundance/Elemental composition, Bott...
# 3     [Antarctic, Bottles or small containers/Aquari...
# 4     [Biomass/Abundance/Elemental composition, Bott...
# ...                                                 ...
# 1496  [Animalia, Behaviour, Benthic animals, Benthos...
# 1497  [Animalia, Benthic animals, Benthos, Coast and...
# 1498  [Benthos, Biomass/Abundance/Elemental composit...
# 1499  [Animalia, Behaviour, Benthic animals, Benthos...
# 1500  [Animalia, Behaviour, Benthic animals, Benthos...
#
#                                                abstract  \
# 0     Sea cucumbers are dominant invertebrates in se...
# 1     The coccolithophore Calcidiscus leptoporus was...
# 2     The present work examines the relationship bet...
# 3     Despite the fact that ocean acidification is c...
# 4     Effects of ocean acidification on Emiliania hu...
# ...                                                 ...
# 1496  Body-size and temperature are the major factor...
# 1497  Ocean acidification (OA) is one of the main co...
# 1498  We investigated ecological, physiological, and...
# 1499  Effects of coastal ocean acidification, other ...
# 1500  Land-based aquaculture facilities experience o...
#
#                                                 authors  \
# 0     [Collard, Marie, Eeckhaut, Igor, Dehairs, Fran...
# 1     [Langer, Gerald, Oetjen, Kerstin, Brenneis, Tina]
# 2                                    [Hermoso, Michael]
# 3     [Trimborn, Scarlett, Brenneis, Tina, Sweet, El...
# 4     [Kottmeier, Dorothee, Rokitta, Sebastian D, To...
# ...                                                 ...
# 1496  [Carey, Nicholas, Harianto, Januar, Byrne, Maria]
# 1497  [Castillo, Nicole, Saavedra, Luisa M, Vargas, ...
# 1498  [Vogel, Nikolas, Fabricius, Katharina Elisabet...
# 1499  [Fernández-Reiriz, Ma José, Range, P, Alvarez-...
# 1500  [Challener, Roberta C, Watts, Stephen A, McCli...
#
#                                                dataLink  year
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969?...  2014
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475?...  2012
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380?...  2015
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406?...  2013
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912?...  2014
# ...                                                 ...   ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079?...  2016
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698?...  2017
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875?...  2015
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645?...  2011
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643?...  2014
#
# [1501 rows x 7 columns]

# %%
df['DOI']
# Out:
# 0       https://doi.pangaea.de/10.1594/PANGAEA.835969
# 1       https://doi.pangaea.de/10.1594/PANGAEA.778475
# 2       https://doi.pangaea.de/10.1594/PANGAEA.861380
# 3       https://doi.pangaea.de/10.1594/PANGAEA.824406
# 4       https://doi.pangaea.de/10.1594/PANGAEA.836912
#                             ...
# 1496    https://doi.pangaea.de/10.1594/PANGAEA.860079
# 1497    https://doi.pangaea.de/10.1594/PANGAEA.890698
# 1498    https://doi.pangaea.de/10.1594/PANGAEA.846875
# 1499    https://doi.pangaea.de/10.1594/PANGAEA.949645
# 1500    https://doi.pangaea.de/10.1594/PANGAEA.835643
# Name: DOI, Length: 1501, dtype: object

# %%
import os
df['Id'] = df.apply(lambda x: os.path.basename(x['DOI']), axis=1)
df['Id']
# Out:
# 0       PANGAEA.835969
# 1       PANGAEA.778475
# 2       PANGAEA.861380
# 3       PANGAEA.824406
# 4       PANGAEA.836912
#              ...
# 1496    PANGAEA.860079
# 1497    PANGAEA.890698
# 1498    PANGAEA.846875
# 1499    PANGAEA.949645
# 1500    PANGAEA.835643
# Name: Id, Length: 1501, dtype: object

# %%
import unidecode
df['dataDirectory'] = df.apply(lambda x:
        unidecode.unidecode(x['authors'][0].split(',')[0].replace(' ','').replace("'",'')) + \
             '_' + str(x['year']) + '_' + os.path.basename(x['DOI']).split('.')[1], axis=1)
df['dataDirectory']
# Out:
# 0                Collard_2014_835969
# 1                 Langer_2012_778475
# 2                Hermoso_2015_861380
# 3               Trimborn_2013_824406
# 4              Kottmeier_2014_836912
#                     ...
# 1496               Carey_2016_860079
# 1497            Castillo_2017_890698
# 1498               Vogel_2015_846875
# 1499    Fernandez-Reiriz_2011_949645
# 1500           Challener_2014_835643
# Name: dataDirectory, Length: 1501, dtype: object

# %%
df.to_csv("metadata.csv", index=False)

# %%
df = pd.read_csv("metadata.csv")
df['keywords'] = df['keywords'].apply(lambda x: eval(x))
df['authors'] = df['authors'].apply(lambda x: eval(x))
df
# Out:
#                                                 DOI  \
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912
# ...                                             ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643
#
#                                                   title  \
# 0     Acid-base physiology response to ocean acidifi...
# 1     Seawater carbonate chemistry, nutrients, and C...
# 2     Control of ambient pH on growth and stable iso...
# 3     Seawater carbonate chemistry and growth, carbo...
# 4     Strong shift from HCO3- to CO2 uptake in Emili...
# ...                                                 ...
# 1496  Sea urchins in a high CO2 world: partitioned e...
# 1497  Seawater carbonate chemistry and immune respon...
# 1498  Calcareous green alga Halimeda tolerates ocean...
# 1499  Seawater carbonate chemistry and physiological...
# 1500  Effects of hypercapnia on aspects of feeding, ...
#
#                                                keywords  \
# 0     [Acid-base regulation, Animalia, Benthic anima...
# 1     [Biomass/Abundance/Elemental composition, Bott...
# 2     [Biomass/Abundance/Elemental composition, Bott...
# 3     [Antarctic, Bottles or small containers/Aquari...
# 4     [Biomass/Abundance/Elemental composition, Bott...
# ...                                                 ...
# 1496  [Animalia, Behaviour, Benthic animals, Benthos...
# 1497  [Animalia, Benthic animals, Benthos, Coast and...
# 1498  [Benthos, Biomass/Abundance/Elemental composit...
# 1499  [Animalia, Behaviour, Benthic animals, Benthos...
# 1500  [Animalia, Behaviour, Benthic animals, Benthos...
#
#                                                abstract  \
# 0     Sea cucumbers are dominant invertebrates in se...
# 1     The coccolithophore Calcidiscus leptoporus was...
# 2     The present work examines the relationship bet...
# 3     Despite the fact that ocean acidification is c...
# 4     Effects of ocean acidification on Emiliania hu...
# ...                                                 ...
# 1496  Body-size and temperature are the major factor...
# 1497  Ocean acidification (OA) is one of the main co...
# 1498  We investigated ecological, physiological, and...
# 1499  Effects of coastal ocean acidification, other ...
# 1500  Land-based aquaculture facilities experience o...
#
#                                                 authors  \
# 0     [Collard, Marie, Eeckhaut, Igor, Dehairs, Fran...
# 1     [Langer, Gerald, Oetjen, Kerstin, Brenneis, Tina]
# 2                                    [Hermoso, Michael]
# 3     [Trimborn, Scarlett, Brenneis, Tina, Sweet, El...
# 4     [Kottmeier, Dorothee, Rokitta, Sebastian D, To...
# ...                                                 ...
# 1496  [Carey, Nicholas, Harianto, Januar, Byrne, Maria]
# 1497  [Castillo, Nicole, Saavedra, Luisa M, Vargas, ...
# 1498  [Vogel, Nikolas, Fabricius, Katharina Elisabet...
# 1499  [Fernández-Reiriz, Ma José, Range, P, Alvarez-...
# 1500  [Challener, Roberta C, Watts, Stephen A, McCli...
#
#                                                dataLink  year              Id  \
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969?...  2014  PANGAEA.835969
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475?...  2012  PANGAEA.778475
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380?...  2015  PANGAEA.861380
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406?...  2013  PANGAEA.824406
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912?...  2014  PANGAEA.836912
# ...                                                 ...   ...             ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079?...  2016  PANGAEA.860079
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698?...  2017  PANGAEA.890698
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875?...  2015  PANGAEA.846875
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645?...  2011  PANGAEA.949645
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643?...  2014  PANGAEA.835643
#
#                      dataDirectory
# 0              Collard_2014_835969
# 1               Langer_2012_778475
# 2              Hermoso_2015_861380
# 3             Trimborn_2013_824406
# 4            Kottmeier_2014_836912
# ...                            ...
# 1496             Carey_2016_860079
# 1497          Castillo_2017_890698
# 1498             Vogel_2015_846875
# 1499  Fernandez-Reiriz_2011_949645
# 1500         Challener_2014_835643
#
# [1501 rows x 9 columns]

# %%
df['keywords'][0]
# Out:
# ['Acid-base regulation',
#  'Animalia',
#  'Benthic animals',
#  'Benthos',
#  'Coast and continental shelf',
#  'Containers and aquaria (20-1000 L or < 1 m**2)',
#  'Echinodermata',
#  'Holothuria parva',
#  'Holothuria scabra',
#  'Indian Ocean',
#  'Laboratory experiment',
#  'Other metabolic rates',
#  'Respiration',
#  'Single species',
#  'Tropical']

# %%
df
# Out:
#                                                 DOI  \
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912
# ...                                             ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643
#
#                                                   title  \
# 0     Acid-base physiology response to ocean acidifi...
# 1     Seawater carbonate chemistry, nutrients, and C...
# 2     Control of ambient pH on growth and stable iso...
# 3     Seawater carbonate chemistry and growth, carbo...
# 4     Strong shift from HCO3- to CO2 uptake in Emili...
# ...                                                 ...
# 1496  Sea urchins in a high CO2 world: partitioned e...
# 1497  Seawater carbonate chemistry and immune respon...
# 1498  Calcareous green alga Halimeda tolerates ocean...
# 1499  Seawater carbonate chemistry and physiological...
# 1500  Effects of hypercapnia on aspects of feeding, ...
#
#                                                keywords  \
# 0     [Acid-base regulation, Animalia, Benthic anima...
# 1     [Biomass/Abundance/Elemental composition, Bott...
# 2     [Biomass/Abundance/Elemental composition, Bott...
# 3     [Antarctic, Bottles or small containers/Aquari...
# 4     [Biomass/Abundance/Elemental composition, Bott...
# ...                                                 ...
# 1496  [Animalia, Behaviour, Benthic animals, Benthos...
# 1497  [Animalia, Benthic animals, Benthos, Coast and...
# 1498  [Benthos, Biomass/Abundance/Elemental composit...
# 1499  [Animalia, Behaviour, Benthic animals, Benthos...
# 1500  [Animalia, Behaviour, Benthic animals, Benthos...
#
#                                                abstract  \
# 0     Sea cucumbers are dominant invertebrates in se...
# 1     The coccolithophore Calcidiscus leptoporus was...
# 2     The present work examines the relationship bet...
# 3     Despite the fact that ocean acidification is c...
# 4     Effects of ocean acidification on Emiliania hu...
# ...                                                 ...
# 1496  Body-size and temperature are the major factor...
# 1497  Ocean acidification (OA) is one of the main co...
# 1498  We investigated ecological, physiological, and...
# 1499  Effects of coastal ocean acidification, other ...
# 1500  Land-based aquaculture facilities experience o...
#
#                                                 authors  \
# 0     [Collard, Marie, Eeckhaut, Igor, Dehairs, Fran...
# 1     [Langer, Gerald, Oetjen, Kerstin, Brenneis, Tina]
# 2                                    [Hermoso, Michael]
# 3     [Trimborn, Scarlett, Brenneis, Tina, Sweet, El...
# 4     [Kottmeier, Dorothee, Rokitta, Sebastian D, To...
# ...                                                 ...
# 1496  [Carey, Nicholas, Harianto, Januar, Byrne, Maria]
# 1497  [Castillo, Nicole, Saavedra, Luisa M, Vargas, ...
# 1498  [Vogel, Nikolas, Fabricius, Katharina Elisabet...
# 1499  [Fernández-Reiriz, Ma José, Range, P, Alvarez-...
# 1500  [Challener, Roberta C, Watts, Stephen A, McCli...
#
#                                                dataLink  year              Id  \
# 0     https://doi.pangaea.de/10.1594/PANGAEA.835969?...  2014  PANGAEA.835969
# 1     https://doi.pangaea.de/10.1594/PANGAEA.778475?...  2012  PANGAEA.778475
# 2     https://doi.pangaea.de/10.1594/PANGAEA.861380?...  2015  PANGAEA.861380
# 3     https://doi.pangaea.de/10.1594/PANGAEA.824406?...  2013  PANGAEA.824406
# 4     https://doi.pangaea.de/10.1594/PANGAEA.836912?...  2014  PANGAEA.836912
# ...                                                 ...   ...             ...
# 1496  https://doi.pangaea.de/10.1594/PANGAEA.860079?...  2016  PANGAEA.860079
# 1497  https://doi.pangaea.de/10.1594/PANGAEA.890698?...  2017  PANGAEA.890698
# 1498  https://doi.pangaea.de/10.1594/PANGAEA.846875?...  2015  PANGAEA.846875
# 1499  https://doi.pangaea.de/10.1594/PANGAEA.949645?...  2011  PANGAEA.949645
# 1500  https://doi.pangaea.de/10.1594/PANGAEA.835643?...  2014  PANGAEA.835643
#
#                      dataDirectory
# 0              Collard_2014_835969
# 1               Langer_2012_778475
# 2              Hermoso_2015_861380
# 3             Trimborn_2013_824406
# 4            Kottmeier_2014_836912
# ...                            ...
# 1496             Carey_2016_860079
# 1497          Castillo_2017_890698
# 1498             Vogel_2015_846875
# 1499  Fernandez-Reiriz_2011_949645
# 1500         Challener_2014_835643
#
# [1501 rows x 9 columns]
