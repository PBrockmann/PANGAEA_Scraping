# %% [markdown]
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)
#
#  * 2023/09/21 - updated
#  * 2022/06/28 - updated
#  * 2021/12/13 - initial revision
#
# <img align="left" width="50%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" >

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://oa-icc.ipsl.fr/checking/OAICC_20230919.csv")
df
# Out:
#                                               Reference  \
# 0     Adeleke, B., Robertson-Andersson, D., & Moodle...
# 1     Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 2     Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 3     Aires, T., Serebryakova, A., Viard, F., Serrão...
# 4     Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
# ...                                                 ...
# 3651  Zittier, Z. M. C., Hirse, T., & Pörtner, H.-O....
# 3652  Ziveri, P., Passaro, M., Incarbona, A., Milazz...
# 3653  Zlatkin, R. L., & Heuer, R. M., 2019. Ocean ac...
# 3654  Zondervan, I., Rost, B., & Riebesell, U., 2002...
# 3655  Zondervan, I., Zeebe, R. E., Rost, B., & Riebe...
#
#                                     DOI             DOI_PANGAEA  \
# 0     doi:10.1016/j.heliyon.2020.e04744                     NaN
# 1                 doi:10.1111/jfd.12417                     NaN
# 2                doi:10.3390/min4010145                     NaN
# 3                doi:10.7717/peerj.4377                     NaN
# 4        doi:10.17576/mjas-2019-2306-10                     NaN
# ...                                 ...                     ...
# 3651      doi:10.1007/s00227-012-2073-8  10.1594/PANGAEA.821402
# 3652          doi:10.1086/BBLv226n3p282  10.1594/PANGAEA.838830
# 3653            doi:10.1098/rsos.191041  10.1594/PANGAEA.912287
# 3654  doi:10.1016/S0022-0981(02)00037-0  10.1594/PANGAEA.726883
# 3655           doi:10.1029/2000GB001321  10.1594/PANGAEA.726883
#
#      Included/Not included            Reason for non inclusion       Country  \
# 0             Not included  < 2 carbonate chemistry parameters  South Africa
# 1             Not included  < 2 carbonate chemistry parameters    EU-Austria
# 2             Not included  < 2 carbonate chemistry parameters           USA
# 3             Not included  < 2 carbonate chemistry parameters   EU-Portugal
# 4             Not included  < 2 carbonate chemistry parameters      Malaysia
# ...                    ...                                 ...           ...
# 3651              Included                                 NaN    EU-Germany
# 3652              Included                                 NaN      EU-Spain
# 3653              Included                                 NaN           USA
# 3654              Included                                 NaN    EU-Germany
# 3655              Included                                 NaN    EU-Germany
#
#       Year
# 0     2020
# 1     2016
# 2     2014
# 3     2018
# 4     2019
# ...    ...
# 3651  2013
# 3652  2014
# 3653  2019
# 3654  2002
# 3655  2001
#
# [3656 rows x 7 columns]

# %%
df['Included/Not included'].unique()
# Out:
# array(['Not included', 'Included'], dtype=object)

# %%
df[df['Included/Not included'] == 'Included'][0:100]
# Out:
#                                               Reference  \
# 2112  Ab Lah, R., Kelaher, B. P., Bucher, D., & Benk...
# 2113  Abarca-Ortega, A., Muñoz-Moya, E., Pacheco Ala...
# 2114  Aberle, N., Schulz, K. G., Stuhr, A., Malzahn,...
# 2115  Agostini, S., Fujimura, H., Higuchi, T., Yuyam...
# 2116  Agostini, S., Harvey, B. P., Milazzo, M., Wada...
# ...                                                 ...
# 2207  Bergstrom, E., Silva, J., Martins, C., & Horta...
# 2208  Bermúdez, R., Winder, M., Stuhr, A., Almén, A....
# 2209  Bernhard, J. M., Wit, J. C., Starczak, V. R., ...
# 2210  Bi, R., Ismar, S., Sommer, U., & Zhao, M., 201...
# 2211  Bi, R., Ismar, S. M. H., Sommer, U., & Zhao, M...
#
#                                          DOI             DOI_PANGAEA  \
# 2112     doi:10.1016/j.marenvres.2018.08.009  10.1594/PANGAEA.902088
# 2113           doi:10.3389/fbioe.2021.813537  10.1594/PANGAEA.945534
# 2114             doi:10.5194/bg-10-1471-2013  10.1594/PANGAEA.832403
# 2115          doi:10.1016/j.crvi.2013.07.003  10.1594/PANGAEA.835319
# 2116                   doi:10.1111/gcb.15749  10.1594/PANGAEA.944056
# ...                                      ...                     ...
# 2207          doi:10.1038/s41598-018-35670-3  10.1594/PANGAEA.914662
# 2208  doi:10.5194/bg-13-6625-2016-supplement  10.1594/PANGAEA.873653
# 2209           doi:10.3389/fmars.2021.643339  10.1594/PANGAEA.932793
# 2210                   doi:10.1002/lno.10429  10.1594/PANGAEA.883475
# 2211  doi:10.5194/bg-15-1029-2018-supplement  10.1594/PANGAEA.901388
#
#      Included/Not included Reason for non inclusion     Country  Year
# 2112              Included                      NaN    Malaysia  2018
# 2113              Included                      NaN       Chile  2022
# 2114              Included                      NaN  EU-Germany  2013
# 2115              Included                      NaN       Japan  2013
# 2116              Included                      NaN       Japan  2021
# ...                    ...                      ...         ...   ...
# 2207              Included                      NaN   Australia  2019
# 2208              Included                      NaN  EU-Germany  2016
# 2209              Included                      NaN         USA  2021
# 2210              Included                      NaN       China  2017
# 2211              Included                      NaN       China  2018
#
# [100 rows x 7 columns]

# %%
df1 = df[df['Included/Not included'] == 'Included']
for i,row in df1['DOI'][0:10].items():
    print(df["DOI"].iloc[i])
# Out:
# doi:10.1016/j.marenvres.2018.08.009
# doi:10.3389/fbioe.2021.813537
# doi:10.5194/bg-10-1471-2013
# doi:10.1016/j.crvi.2013.07.003
# doi:10.1111/gcb.15749
# doi:10.1038/s41598-018-29251-7
# doi:10.1016/j.ecss.2020.106640
# doi:10.1371/journal.pone.0209823
# doi:10.1038/s41598-019-56621-6
# doi:10.1111/maec.12282

# %%
a = df[df['Included/Not included'] == 'Included'].groupby("Country").size()
a.sort_values(inplace=True, ascending=False)
b = a[a >= 5]
#b = a
b
# Out:
# Country
# USA                            323
# EU-Germany                     242
# China                          147
# Australia                      147
# EU-UK                          121
# EU-France                       74
# EU-Spain                        48
# Japan                           47
# EU-Portugal                     44
# Canada                          40
# EU-Norway                       32
# EU-Sweden                       31
# EU-Italy                        30
# New Zealand                     22
# Chile                           21
# EU-Belgium                      19
# EU-Monaco                       19
# EU-The Netherlands              16
# Israel                          12
# China, Hong Kong                10
# Republic of Korea                9
# EU-Greece                        9
# Brazil                           8
# India                            7
# EU-Finland                       6
# China, Taiwan                    6
# The Kingdom of Saudi Arabia      6
# EU-UK (Bermuda)                  6
# dtype: int64

# %%
ax = b.plot.bar(zorder=3, figsize=[12,5], width=0.5, xlabel="")
ax.grid(axis='y', zorder=0, color='gainsboro', linestyle='--')
plt.xticks(rotation=30, horizontalalignment='right')
plt.show()

# %%
# Country2 = EU-xxxx as EU
df['Country2'] = df['Country'].apply(lambda x: "EU" if str(x).startswith("EU-") else x)
# Country2 = EU-xxxx as xxxx
df['Country3'] = df['Country'].apply(lambda x: x.split('-')[1] if str(x).startswith("EU-") else x)
df
# Out:
#                                               Reference  \
# 0     Adeleke, B., Robertson-Andersson, D., & Moodle...
# 1     Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 2     Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 3     Aires, T., Serebryakova, A., Viard, F., Serrão...
# 4     Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
# ...                                                 ...
# 3651  Zittier, Z. M. C., Hirse, T., & Pörtner, H.-O....
# 3652  Ziveri, P., Passaro, M., Incarbona, A., Milazz...
# 3653  Zlatkin, R. L., & Heuer, R. M., 2019. Ocean ac...
# 3654  Zondervan, I., Rost, B., & Riebesell, U., 2002...
# 3655  Zondervan, I., Zeebe, R. E., Rost, B., & Riebe...
#
#                                     DOI             DOI_PANGAEA  \
# 0     doi:10.1016/j.heliyon.2020.e04744                     NaN
# 1                 doi:10.1111/jfd.12417                     NaN
# 2                doi:10.3390/min4010145                     NaN
# 3                doi:10.7717/peerj.4377                     NaN
# 4        doi:10.17576/mjas-2019-2306-10                     NaN
# ...                                 ...                     ...
# 3651      doi:10.1007/s00227-012-2073-8  10.1594/PANGAEA.821402
# 3652          doi:10.1086/BBLv226n3p282  10.1594/PANGAEA.838830
# 3653            doi:10.1098/rsos.191041  10.1594/PANGAEA.912287
# 3654  doi:10.1016/S0022-0981(02)00037-0  10.1594/PANGAEA.726883
# 3655           doi:10.1029/2000GB001321  10.1594/PANGAEA.726883
#
#      Included/Not included            Reason for non inclusion       Country  \
# 0             Not included  < 2 carbonate chemistry parameters  South Africa
# 1             Not included  < 2 carbonate chemistry parameters    EU-Austria
# 2             Not included  < 2 carbonate chemistry parameters           USA
# 3             Not included  < 2 carbonate chemistry parameters   EU-Portugal
# 4             Not included  < 2 carbonate chemistry parameters      Malaysia
# ...                    ...                                 ...           ...
# 3651              Included                                 NaN    EU-Germany
# 3652              Included                                 NaN      EU-Spain
# 3653              Included                                 NaN           USA
# 3654              Included                                 NaN    EU-Germany
# 3655              Included                                 NaN    EU-Germany
#
#       Year      Country2      Country3
# 0     2020  South Africa  South Africa
# 1     2016            EU       Austria
# 2     2014           USA           USA
# 3     2018            EU      Portugal
# 4     2019      Malaysia      Malaysia
# ...    ...           ...           ...
# 3651  2013            EU       Germany
# 3652  2014            EU         Spain
# 3653  2019           USA           USA
# 3654  2002            EU       Germany
# 3655  2001            EU       Germany
#
# [3656 rows x 9 columns]

# %%
df[df['Country'].isna()]
# Out:
#                                              Reference  DOI DOI_PANGAEA  \
# 890  Dworjanyn, S. A., & Byrne, M., 2018. Impacts o...  NaN         NaN
#
#     Included/Not included Reason for non inclusion Country Year Country2  \
# 890          Not included   No answer from authors     NaN  NaN      NaN
#
#     Country3
# 890      NaN

# %%
len(df)
# Out:
# 3656

# %%
df.dropna(subset='Country', inplace=True)
df
# Out:
#                                               Reference  \
# 0     Adeleke, B., Robertson-Andersson, D., & Moodle...
# 1     Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 2     Ahrendt, S., Mobberley, J., Visscher, P., Koss...
# 3     Aires, T., Serebryakova, A., Viard, F., Serrão...
# 4     Al-Awlaqi, N. A. N., Shazili, N. A. M., & Yuso...
# ...                                                 ...
# 3651  Zittier, Z. M. C., Hirse, T., & Pörtner, H.-O....
# 3652  Ziveri, P., Passaro, M., Incarbona, A., Milazz...
# 3653  Zlatkin, R. L., & Heuer, R. M., 2019. Ocean ac...
# 3654  Zondervan, I., Rost, B., & Riebesell, U., 2002...
# 3655  Zondervan, I., Zeebe, R. E., Rost, B., & Riebe...
#
#                                     DOI             DOI_PANGAEA  \
# 0     doi:10.1016/j.heliyon.2020.e04744                     NaN
# 1                 doi:10.1111/jfd.12417                     NaN
# 2                doi:10.3390/min4010145                     NaN
# 3                doi:10.7717/peerj.4377                     NaN
# 4        doi:10.17576/mjas-2019-2306-10                     NaN
# ...                                 ...                     ...
# 3651      doi:10.1007/s00227-012-2073-8  10.1594/PANGAEA.821402
# 3652          doi:10.1086/BBLv226n3p282  10.1594/PANGAEA.838830
# 3653            doi:10.1098/rsos.191041  10.1594/PANGAEA.912287
# 3654  doi:10.1016/S0022-0981(02)00037-0  10.1594/PANGAEA.726883
# 3655           doi:10.1029/2000GB001321  10.1594/PANGAEA.726883
#
#      Included/Not included            Reason for non inclusion       Country  \
# 0             Not included  < 2 carbonate chemistry parameters  South Africa
# 1             Not included  < 2 carbonate chemistry parameters    EU-Austria
# 2             Not included  < 2 carbonate chemistry parameters           USA
# 3             Not included  < 2 carbonate chemistry parameters   EU-Portugal
# 4             Not included  < 2 carbonate chemistry parameters      Malaysia
# ...                    ...                                 ...           ...
# 3651              Included                                 NaN    EU-Germany
# 3652              Included                                 NaN      EU-Spain
# 3653              Included                                 NaN           USA
# 3654              Included                                 NaN    EU-Germany
# 3655              Included                                 NaN    EU-Germany
#
#       Year      Country2      Country3
# 0     2020  South Africa  South Africa
# 1     2016            EU       Austria
# 2     2014           USA           USA
# 3     2018            EU      Portugal
# 4     2019      Malaysia      Malaysia
# ...    ...           ...           ...
# 3651  2013            EU       Germany
# 3652  2014            EU         Spain
# 3653  2019           USA           USA
# 3654  2002            EU       Germany
# 3655  2001            EU       Germany
#
# [3655 rows x 9 columns]

# %%
df['Country'].str.startswith("EU-")
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 3651     True
# 3652     True
# 3653    False
# 3654     True
# 3655     True
# Name: Country, Length: 3655, dtype: bool

# %%
df[df['Country'].str.startswith("EU-")]
# Out:
#                                               Reference  \
# 1     Ahnelt, H., Schade, F. M., & Wegner, M., 2016....
# 3     Aires, T., Serebryakova, A., Viard, F., Serrão...
# 5     Al-Janabi, B., Kruse, I., Graiff, A., Winde, V...
# 6     Alenius, B., & Munguia, P., 2012. Effects of p...
# 8     Allison, N., Cole, C., Hintz, C., Hintz, K., &...
# ...                                                 ...
# 3650  Zittier, Z. M. C., Bock, C., Lannig, G., & Pör...
# 3651  Zittier, Z. M. C., Hirse, T., & Pörtner, H.-O....
# 3652  Ziveri, P., Passaro, M., Incarbona, A., Milazz...
# 3654  Zondervan, I., Rost, B., & Riebesell, U., 2002...
# 3655  Zondervan, I., Zeebe, R. E., Rost, B., & Riebe...
#
#                                     DOI             DOI_PANGAEA  \
# 1                 doi:10.1111/jfd.12417                     NaN
# 3                doi:10.7717/peerj.4377                     NaN
# 5      doi:10.1371/journal.pone.0152948                     NaN
# 6      doi:10.1080/10236244.2012.727235                     NaN
# 8      doi:10.1016/j.palaeo.2018.06.015                     NaN
# ...                                 ...                     ...
# 3650    doi:10.1016/j.jembe.2015.08.001  10.1594/PANGAEA.867517
# 3651      doi:10.1007/s00227-012-2073-8  10.1594/PANGAEA.821402
# 3652          doi:10.1086/BBLv226n3p282  10.1594/PANGAEA.838830
# 3654  doi:10.1016/S0022-0981(02)00037-0  10.1594/PANGAEA.726883
# 3655           doi:10.1029/2000GB001321  10.1594/PANGAEA.726883
#
#      Included/Not included            Reason for non inclusion      Country  \
# 1             Not included  < 2 carbonate chemistry parameters   EU-Austria
# 3             Not included  < 2 carbonate chemistry parameters  EU-Portugal
# 5             Not included  < 2 carbonate chemistry parameters   EU-Germany
# 6             Not included  < 2 carbonate chemistry parameters    EU-Sweden
# 8             Not included  < 2 carbonate chemistry parameters        EU-UK
# ...                    ...                                 ...          ...
# 3650              Included                                 NaN   EU-Germany
# 3651              Included                                 NaN   EU-Germany
# 3652              Included                                 NaN     EU-Spain
# 3654              Included                                 NaN   EU-Germany
# 3655              Included                                 NaN   EU-Germany
#
#       Year Country2  Country3
# 1     2016       EU   Austria
# 3     2018       EU  Portugal
# 5     2016       EU   Germany
# 6     2012       EU    Sweden
# 8     2018       EU        UK
# ...    ...      ...       ...
# 3650  2015       EU   Germany
# 3651  2013       EU   Germany
# 3652  2014       EU     Spain
# 3654  2002       EU   Germany
# 3655  2001       EU   Germany
#
# [1387 rows x 9 columns]

# %%
a = df.groupby("Country2").size()
a.sort_values(inplace=True, ascending=False)
b = a[a >= 5]
b
# Out:
# Country2
# EU                             1387
# USA                             756
# China                           470
# Australia                       399
# Japan                            93
# Canada                           78
# New Zealand                      74
# Chile                            70
# Brazil                           50
# Republic of Korea                48
# India                            46
# Israel                           31
# China, Hong Kong                 18
# Malaysia                         17
# China, Taiwan                    15
# South Africa                     12
# Indonesia                        11
# Mexico                           11
# Argentina                        10
# Philippines                       8
# The Kingdom of Saudi Arabia       8
# Egypt                             6
# Panama                            5
# dtype: int64

# %%
ax = b.plot.bar(zorder=3, figsize=[10,5], width=0.5, xlabel="")
ax.grid(axis='y', zorder=0, color='gainsboro', linestyle='--')
plt.xticks(rotation=30, horizontalalignment='right')
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import random

x = [random.randint(-180, 180) for p in range(0, 149)]
y = [random.randint(-90, 90) for p in range(0, 149)]
s = [random.randint(1, 1000) for p in range(0, 149)]

fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(1,1,1, projection=ccrs.Robinson())

ax.set_global()

ax.add_feature(cfeature.COASTLINE, edgecolor="gray")
ax.add_feature(cfeature.BORDERS, edgecolor="gray")
ax.add_feature(cfeature.OCEAN, color="lightgray")
ax.gridlines()

scatter = plt.scatter(x, y, s=s, transform=ccrs.PlateCarree(), alpha=0.5)

handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6, num=5)
legend2 = ax.legend(handles, labels, loc="upper right", title="Sizes", 
                    bbox_to_anchor=(1.12, 1), frameon=False, labelspacing=1.9)

plt.show()

# %% [markdown]
# #### Different ways to locate from a standard name
# - geopy
# - pycountry + countryinfo

# %%
# https://towardsdatascience.com/things-to-do-with-latitude-longitude-data-using-geopy-python-1d356ed1ae30
from geopy.geocoders import Nominatim
geocoder = Nominatim(user_agent = 'your_app_name')

# %%
# pycountry provides ISO 3166 codes
import pycountry
pycountry.countries.get(name='Taiwan, Province of China').alpha_3
pycountry.countries.get(name='Bermuda').alpha_3
# Out:
# 'BMU'

# %%
# countryinfo provides location from alpha-2 iso 3166 code
from countryinfo import CountryInfo
country = CountryInfo('')
country.latlng()
# Out:
# [15, 39]

# %%
#text = "UK" # -3.2765753, 54.7023545
#text = "Bermuda" # -64.7603583, 32.3018217
text = "UK (Bermuda)" # -1.4789788, 52.5056354
text = "Brunei Darussalam"
text = "The Bahamas"
text = "French Polynesia"
text = "Estonia"
text = "Malaysia"
text = "Kingdom of Saudi Arabia"
text = "China, Hong Kong"
#text = "Korea"
text = "Taiwan"

location = geocoder.geocode(text)

fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(1,1,1, projection=ccrs.Robinson())

ax.set_global()

ax.add_feature(cfeature.COASTLINE, edgecolor="gray")
ax.add_feature(cfeature.BORDERS, edgecolor="gray")
ax.add_feature(cfeature.OCEAN, color="lightgray")
ax.gridlines()

scatter = plt.plot(location.longitude, location.latitude, transform=ccrs.PlateCarree(),
                  color='r', marker='.', markersize=10)

plt.show()

print(location.longitude, location.latitude)
# Out:
# 120.83537694479215 23.5983227

# %% [markdown]
# ### Included papers

# %%
a1 = df[df['Included/Not included'] == 'Included'].groupby("Country2").size()
a1.sort_values(inplace=True, ascending=False)
#b1 = a1[a1 >= 5]
b1 = a1
b1
# Out:
# Country2
# EU                             714
# USA                            323
# Australia                      147
# China                          147
# Japan                           47
# Canada                          40
# New Zealand                     22
# Chile                           21
# Israel                          12
# China, Hong Kong                10
# Republic of Korea                9
# Brazil                           8
# India                            7
# China, Taiwan                    6
# The Kingdom of Saudi Arabia      6
# Mexico                           4
# South Africa                     4
# Philippines                      4
# Malaysia                         3
# Panama                           2
# Colombia                         2
# Argentina                        2
# New Caledonia                    1
# Cuba                             1
# Kuwait                           1
# Angola                           1
# dtype: int64

# %%
b1.index
# Out:
# Index(['EU', 'USA', 'Australia', 'China', 'Japan', 'Canada', 'New Zealand',
#        'Chile', 'Israel', 'China, Hong Kong', 'Republic of Korea', 'Brazil',
#        'India', 'China, Taiwan', 'The Kingdom of Saudi Arabia', 'Mexico',
#        'South Africa', 'Philippines', 'Malaysia', 'Panama', 'Colombia',
#        'Argentina', 'New Caledonia', 'Cuba', 'Kuwait', 'Angola'],
#       dtype='object', name='Country2')

# %%
countries = ["UK","Bermuda","UK (Bermuda)"]

for c in countries:
    location = geocoder.geocode(c)
    print(c, location.longitude, location.latitude)
# Out:
# UK 20.5447525 6.3110548
# Bermuda -64.7815286 32.2937417
# UK (Bermuda) -1.4789788 52.5056354

# %%
# Correct 'UK (Bermuda)' to be able to locate it properly
b1.rename(index={'UK (Bermuda)':'Bermuda'}, inplace=True)
b1.rename(index={'China, Taiwan':'Taiwan'}, inplace=True)

b1.index
# Out:
# Index(['EU', 'USA', 'Australia', 'China', 'Japan', 'Canada', 'New Zealand',
#        'Chile', 'Israel', 'China, Hong Kong', 'Republic of Korea', 'Brazil',
#        'India', 'Taiwan', 'The Kingdom of Saudi Arabia', 'Mexico',
#        'South Africa', 'Philippines', 'Malaysia', 'Panama', 'Colombia',
#        'Argentina', 'New Caledonia', 'Cuba', 'Kuwait', 'Angola'],
#       dtype='object', name='Country2')

# %%
b1_geocode = b1.index.map(lambda x: geocoder.geocode(x))

# %%
b1[b1.index == 'France'].index.map(lambda x: geocoder.geocode(x))
# Out:
# Index([], dtype='object', name='Country2')

# %%
b1_geocode
# Out:
# Index([                                          ('Eu, Dieppe, Seine-Maritime, Normandie, France métropolitaine, 76260, France', (50.0491699, 1.4175744)),
#                                                                                                              ('United States', (39.7837304, -100.445882)),
#                                                                                                                     ('Australia', (-24.7761086, 134.755)),
#                                                                                   ('China, Nuevo León, México', (25.491579899999998, -98.98111150455688)),
#                                                                                                                         ('日本', (36.5748441, 139.2394179)),
#                                                                                                                     ('Canada', (61.0666922, -107.991707)),
#                                                                                                    ('New Zealand / Aotearoa', (-41.5000831, 172.8344077)),
#                                                                                                                     ('Chile', (-31.7613365, -71.3187697)),
#                                                                       ('Israel, Preston County, West Virginia, United States', (39.3181528, -79.8109014)),
#                                                                                     ('香港島 Hong Kong Island, 香港 Hong Kong, 中国', (22.2793278, 114.1628131)),
#                                                                                                                        ('대한민국', (36.638392, 127.6961188)),
#                                                                                                                          ('Brasil', (-10.3333333, -53.2)),
#                                                                                                                       ('India', (22.3511148, 78.6677428)),
#                                                                                                                  ('臺灣', (23.5983227, 120.83537694479215)),
#        ('The Kingdom of Saudi Arabia, Lituhi Road, Maguruwe, Tandika, Temeke MC, Dar es Salaam, Coastal Zone, 38656, Tanzania', (-6.8638235, 39.2551949)),
#                                                                                                   ('Ciudad de México, México', (19.4326296, -99.1331785)),
#                                                                                                                ('South Africa', (-28.8166236, 24.991639)),
#                                                                                                                ('Philippines', (12.7503486, 122.7312101)),
#                                                                                                                    ('Malaysia', (4.5693754, 102.2656823)),
#                                                                                                                       ('Panamá', (8.559559, -81.1308434)),
#                                                                                                                     ('Colombia', (4.099917, -72.9088133)),
#                                                                                                                 ('Argentina', (-34.9964963, -64.9672817)),
#                                                                    ('Nouvelle-Calédonie (zone économique exclusive)', (-20.63784275, 161.21176261225781)),
#                                                                                                                       ('Cuba', (23.0131338, -80.8328748)),
#                                                                                        ('مدينة الكويت, العاصمة, 15005, الكويت', (29.3796532, 47.9734174)),
#                                                                                                                     ('Angola', (-11.8775768, 17.5691241))],
#       dtype='object', name='Country2')

# %%
# EU is located wrongly but it is ok

# %%
b1_lon = [g.longitude for g in b1_geocode]
b1_lat = [g.latitude for g in b1_geocode]

# %%
b1_lon[0], b1_lat[0], b1[0]
# Out:
# (1.4175744, 50.0491699, 714)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(1,1,1, projection=ccrs.Robinson())

ax.set_global()

ax.add_feature(cfeature.COASTLINE, edgecolor="gray")
ax.add_feature(cfeature.BORDERS, edgecolor="gray")
ax.add_feature(cfeature.OCEAN, color="lightgray")
ax.gridlines()

scaleFactor = 5
scatter = plt.scatter(b1_lon, b1_lat, b1*scaleFactor, transform=ccrs.PlateCarree(), 
                      alpha=0.8, color='royalblue', edgecolor='black')

#for i in range(0,len(b1)):
#    if b1[i] >= 50:
#        plt.text(b1_lon[i], b1_lat[i], b1[i], transform=ccrs.PlateCarree(), 
#             ha="center", va="center", alpha=0.8, fontsize=8)

handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6, num=[1,2,5,10,20,50,100],
                                         func=lambda x: x/scaleFactor)
legend2 = ax.legend(handles, labels, loc="upper right", title="Number of papers\nincluded", 
                    bbox_to_anchor=(1.13, 1), frameon=False, labelspacing=1.6)

plt.show()

# %%
b1
# Out:
# Country2
# EU                             714
# USA                            323
# Australia                      147
# China                          147
# Japan                           47
# Canada                          40
# New Zealand                     22
# Chile                           21
# Israel                          12
# China, Hong Kong                10
# Republic of Korea                9
# Brazil                           8
# India                            7
# Taiwan                           6
# The Kingdom of Saudi Arabia      6
# Mexico                           4
# South Africa                     4
# Philippines                      4
# Malaysia                         3
# Panama                           2
# Colombia                         2
# Argentina                        2
# New Caledonia                    1
# Cuba                             1
# Kuwait                           1
# Angola                           1
# dtype: int64

# %%
a1 = df[(df['Country'].str.startswith("EU-")) & (df['Included/Not included'] == 'Included')].groupby("Country3").size()
a1.sort_values(inplace=True, ascending=False)
#b1 = a1[a1 >= 5]
b1 = a1
b1
# Out:
# Country3
# Germany                242
# UK                     122
# France                  74
# Spain                   48
# Portugal                44
# Norway                  32
# Sweden                  31
# Italy                   30
# Belgium                 19
# Monaco                  19
# The Netherlands         16
# Greece                   9
# Finland                  6
# UK (Bermuda)             6
# Denmark                  4
# Estonia                  3
# Turkey                   3
# Czech Republic           2
# Iceland                  1
# Poland                   1
# France (La Réunion)      1
# Switzerland              1
# dtype: int64

# %%
b1.rename(index={'UK (Bermuda)':'Bermuda'}, inplace=True)

# %%
b1_geocode = b1.index.map(lambda x: geocoder.geocode(x))
b1_geocode
# Out:
# Index([('Germany, West Wheatfield Township, Indiana County, Pennsylvania, 15949, United States', (40.4203479, -79.1166983)),
#                                                                            ('Ouaka, Centrafrique', (6.3110548, 20.5447525)),
#                                                                                          ('France', (46.603354, 1.8883335)),
#                                                                                        ('España', (39.3260685, -4.8379791)),
#                                                                                      ('Portugal', (39.6621648, -8.1353519)),
#                                                                                  ('Norge', (64.5731537, 11.52803643954819)),
#                                             ('Sweden, Oxford County, Maine, 04040, United States', (44.133435, -70.822678)),
#                                                                                         ('Italia', (42.6384261, 12.674297)),
#                                                                    ('België / Belgique / Belgien', (50.6402809, 4.6667145)),
#                                                                                         ('Monaco', (43.7323492, 7.4276832)),
#                                                                             ('Nederland', (52.24764975, 5.541246849406163)),
#                                       ('Town of Greece, Monroe County, New York, United States', (43.2097838, -77.6930602)),
#                                                                               ('Suomi / Finland', (63.2467777, 25.9209164)),
#                                                                                      ('Bermuda', (32.2937417, -64.7815286)),
#                                                                                        ('Danmark', (55.670249, 10.3333283)),
#                                                                                         ('Eesti', (58.7523778, 25.3319078)),
#                                                                                       ('Türkiye', (38.9597594, 34.9249653)),
#                                                                                         ('Česko', (49.7439047, 15.3381061)),
#                                                                                       ('Ísland', (64.9841821, -18.1059013)),
#                                                                                          ('Polska', (52.215933, 19.134422)),
#                                                                           ('La Réunion, France', (-21.1309332, 55.5265771)),
#                                                                 ('Schweiz/Suisse/Svizzera/Svizra', (46.7985624, 8.2319736))],
#       dtype='object', name='Country3')

# %%
b1_lon = [g.longitude for g in b1_geocode]
b1_lat = [g.latitude for g in b1_geocode]

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(1,1,1, projection=ccrs.TransverseMercator(central_longitude=15, approx=True))

ax.set_extent([-10, 35, 34, 69])

ax.add_feature(cfeature.COASTLINE, edgecolor="gray")
ax.add_feature(cfeature.BORDERS, edgecolor="gray")
ax.add_feature(cfeature.OCEAN, color="lightgray")
ax.gridlines()

scaleFactor = 8
scatter = plt.scatter(b1_lon, b1_lat, b1*scaleFactor, transform=ccrs.PlateCarree(), 
                      alpha=0.8, color='royalblue', edgecolor='black')

#for i in range(0,len(b1)):
#    if b1[i] >= 10:
#        plt.text(b1_lon[i], b1_lat[i], b1[i], transform=ccrs.PlateCarree(), 
#             ha="center", va="center", alpha=0.8, fontsize=8)

handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6, num=[1,2,5,10,20,50,100],
                                         func=lambda x: x/scaleFactor)
legend2 = ax.legend(handles, labels, loc="upper right", title="Number of papers\nincluded", 
                    bbox_to_anchor=(1.25, 1), frameon=False, labelspacing=1.6)

plt.show()

# %% [markdown]
# ### Not included papers

# %%
df[df['Reason for non inclusion'] == 'No answer from authors']
# Out:
#                                               Reference  \
# 573   Achlatis, M., van der Zande, R. M., Schönberg,...
# 574   Agnalt, A.-L., Grefsrud, E. S., Farestveit, E....
# 575   Aguayo, P., Campos, V. L., Henríquez, C., Oliv...
# 576   Albert, G., Hepburn, C. D., Pajusalu, L., Paal...
# 577   Albright, R., Bland, C., Gillette, P., Serafy,...
# ...                                                 ...
# 2091  Zhu, X., Liao, H., Yang, Z., Peng, C., Lu, W.,...
# 2092  Zhu, Z., Qu, P., Gale, J., Fu, F., & Hutchins,...
# 2093  Zittier, Z. M. C., Bock, C., Sukhotin, A. A., ...
# 2094  Ziveri, P., Thoms, S., Probert, I., Geisen, M....
# 2095  Zweng, R. C., Koch, M. S., & Bowes, G., 2018. ...
#
#                                     DOI DOI_PANGAEA Included/Not included  \
# 573      doi:10.1038/s41598-017-10947-1         NaN          Not included
# 574         doi:10.5194/bg-10-7883-2013         NaN          Not included
# 575   doi:10.3390/microorganisms8121924         NaN          Not included
# 576      doi:10.1007/s10811-019-01953-z         NaN          Not included
# 577     doi:10.1016/j.jembe.2012.05.017         NaN          Not included
# ...                                 ...         ...                   ...
# 2091      doi:10.1016/j.fsi.2020.01.036         NaN          Not included
# 2092        doi:10.5194/bg-14-5281-2017         NaN          Not included
# 2093      doi:10.1007/s00300-018-2362-x         NaN          Not included
# 2094         doi:10.5194/bg-9-1025-2012         NaN          Not included
# 2095     doi:10.1038/s41598-018-27333-0         NaN          Not included
#
#      Reason for non inclusion     Country  Year   Country2   Country3
# 573    No answer from authors   Australia  2017  Australia  Australia
# 574    No answer from authors   EU-Norway  2013         EU     Norway
# 575    No answer from authors       Chile  2020      Chile      Chile
# 576    No answer from authors  EU-Estonia  2019         EU    Estonia
# 577    No answer from authors         USA  2012        USA        USA
# ...                       ...         ...   ...        ...        ...
# 2091   No answer from authors       China  2020      China      China
# 2092   No answer from authors         USA  2017        USA        USA
# 2093   No answer from authors  EU-Germany  2018         EU    Germany
# 2094   No answer from authors    EU-Spain  2012         EU      Spain
# 2095   No answer from authors         USA  2018        USA        USA
#
# [1522 rows x 9 columns]

# %%
#a2 = df[df['Included/Not included'] == 'Not included'].groupby("Country3").size()
a2 = df[df['Reason for non inclusion'] == 'No answer from authors'].groupby("Country3").size()
a2.sort_values(inplace=True, ascending=False)
#b2 = a2[a2 >= 5]
b2 = a2
b2
# Out:
# Country3
# USA                            339
# Australia                      219
# China                          198
# UK                              99
# Germany                         74
# Portugal                        65
# Spain                           60
# Italy                           50
# Chile                           46
# Japan                           37
# New Zealand                     34
# Brazil                          28
# Canada                          27
# France                          27
# Sweden                          25
# Norway                          24
# India                           24
# Republic of Korea               23
# Israel                          12
# Indonesia                       10
# Belgium                          9
# China, Taiwan                    7
# The Netherlands                  7
# Monaco                           7
# China, Hong Kong                 7
# Finland                          6
# Turkey                           5
# Poland                           5
# Denmark                          5
# Malaysia                         4
# Egypt                            4
# Philippines                      3
# Greece                           3
# New Caledonia                    3
# South Africa                     3
# Mexico                           3
# The Kingdom of Saudi Arabia      2
# Thailand                         2
# Argentina                        2
# Kuwait                           2
# USA, Guam                        2
# South Korea                      1
# Peru                             1
# Panama                           1
# Namibia                          1
# The Bahamas                      1
# France, New Caledonia            1
# Estonia                          1
# Brunei Darussalam                1
# UK (Bermuda)                     1
# Bangladesh                       1
# dtype: int64

# %%
# Correct 'UK (Bermuda)' to be able to locate it properly
b2.rename(index={'UK (Bermuda)':'Bermuda'}, inplace=True)
b2.rename(index={'China, Taiwan':'Taiwan'}, inplace=True)

b2.index
# Out:
# Index(['USA', 'Australia', 'China', 'UK', 'Germany', 'Portugal', 'Spain',
#        'Italy', 'Chile', 'Japan', 'New Zealand', 'Brazil', 'Canada', 'France',
#        'Sweden', 'Norway', 'India', 'Republic of Korea', 'Israel', 'Indonesia',
#        'Belgium', 'Taiwan', 'The Netherlands', 'Monaco', 'China, Hong Kong',
#        'Finland', 'Turkey', 'Poland', 'Denmark', 'Malaysia', 'Egypt',
#        'Philippines', 'Greece', 'New Caledonia', 'South Africa', 'Mexico',
#        'The Kingdom of Saudi Arabia', 'Thailand', 'Argentina', 'Kuwait',
#        'USA, Guam', 'South Korea', 'Peru', 'Panama', 'Namibia', 'The Bahamas',
#        'France, New Caledonia', 'Estonia', 'Brunei Darussalam', 'Bermuda',
#        'Bangladesh'],
#       dtype='object', name='Country3')

# %%
b2_geocode = b2.index.map(lambda x: geocoder.geocode(x))

# %%
b2_lon = [g.longitude for g in b2_geocode]
b2_lat = [g.latitude for g in b2_geocode]

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(1,1,1, projection=ccrs.Robinson())

ax.set_global()

ax.add_feature(cfeature.COASTLINE, edgecolor="gray")
ax.add_feature(cfeature.BORDERS, edgecolor="gray")
ax.add_feature(cfeature.OCEAN, color="lightgray")
ax.gridlines()

scaleFactor = 8
scatter = plt.scatter(b2_lon, b2_lat, b2*scaleFactor, transform=ccrs.PlateCarree(), 
                      alpha=0.8, color='darkorange', edgecolor='black')

handles, labels = scatter.legend_elements(prop="sizes", alpha=0.6, num=[1,2,5,10,20,50,100],
                                         func=lambda x: x/scaleFactor)
legend2 = ax.legend(handles, labels, loc="upper right", title="Number of papers with\nno answer from authors", 
                    bbox_to_anchor=(1.13, 1), frameon=False, labelspacing=1.6)

plt.show()

# %%
b2
# Out:
# Country3
# USA                            339
# Australia                      219
# China                          198
# UK                              99
# Germany                         74
# Portugal                        65
# Spain                           60
# Italy                           50
# Chile                           46
# Japan                           37
# New Zealand                     34
# Brazil                          28
# Canada                          27
# France                          27
# Sweden                          25
# Norway                          24
# India                           24
# Republic of Korea               23
# Israel                          12
# Indonesia                       10
# Belgium                          9
# Taiwan                           7
# The Netherlands                  7
# Monaco                           7
# China, Hong Kong                 7
# Finland                          6
# Turkey                           5
# Poland                           5
# Denmark                          5
# Malaysia                         4
# Egypt                            4
# Philippines                      3
# Greece                           3
# New Caledonia                    3
# South Africa                     3
# Mexico                           3
# The Kingdom of Saudi Arabia      2
# Thailand                         2
# Argentina                        2
# Kuwait                           2
# USA, Guam                        2
# South Korea                      1
# Peru                             1
# Panama                           1
# Namibia                          1
# The Bahamas                      1
# France, New Caledonia            1
# Estonia                          1
# Brunei Darussalam                1
# Bermuda                          1
# Bangladesh                       1
# dtype: int64
